# %% [markdown]
# <font color='#2F4F4F'>To use this notebook on Colaboratory, you will need to make a copy of it. Go to File > Save a Copy in Drive. You can then use the new copy that will appear in the new tab.</font>

# %% [markdown]
# # <font color='#2F4F4F'>AfterWork Data Science: Web Scraping with Python</font>

# %% [markdown]
# ## <font color='#2F4F4F'>Prerequisites</font>

# %%
# We first import the required libraries
# ---
#
import pandas as pd             # library for data manupation
import requests                 # library for fetching a web page 
from bs4 import BeautifulSoup   # library for extrating contents from a webpage

# %% [markdown]
# ## <font color='#2F4F4F'>Step 1: Obtaining our Data</font>

# %%
# PigiaMe: https://www.pigiame.co.ke/it-software-jobs
# ---
#
pigia_me = requests.get('https://www.pigiame.co.ke/it-software-jobs')
pigia_me
# Out:
# <Response [200]>

# %%
# MyJobMag: https://www.myjobmag.co.ke/jobs-by-field/information-technology
# ---
#
# YOUR CODE GOES HERE
MyJobMag = requests.get('https://www.myjobmag.co.ke/jobs-by-field/information-technology')
MyJobMag
# Out:
# <Response [200]>

# %%
# KenyanJob: https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133
# ---
#
# YOUR CODE GOES HERE
KenyanJob = requests.get('https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133')
KenyanJob
# Out:
# <Response [200]>

# %%
# - A status_code starting with 2 indicates success.
# - A status_code starting with 4 or 5 indicates an error.

# %% [markdown]
# ## <font color='#2F4F4F'>Step 2: Parsing</font>

# %%
# Parsing our document: pigia_me
# ---
# 
pigia = BeautifulSoup(pigia_me.text, "html.parser")
print(pigia.prettify())
# Out:
# <!DOCTYPE html>
# <html class="" lang="en" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#">
#  <head>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <meta content="force" name="imagemode">
#    <link href="https://i.roamcdn.net" rel="dns-prefetch"/>
#    <link href="https://i.roamcdn.net" rel="preconnect"/>
#    <link href="https://adservice.google.com" rel="dns-prefetch"/>
#    <link href="https://adservice.google.com" rel="preconnect"/>
#    <link href="https://cdn.onesignal.com" rel="dns-prefetch"/>
#    <link href="https://cdn.onesignal.com" rel="preconnect"/>
#    <link href="https://connect.facebook.net" rel="dns-prefetch"/>
#    <link href="https://connect.facebook.net" rel="preconnect"/>
#    <link href="https://creativecdn.com" rel="dns-prefetch"/>
#    <link href="https://creativecdn.com" rel="preconnect"/>
#    <link href="https://googleads.g.doubleclick.net" rel="dns-prefetch"/>
#    <link href="https://googleads.g.doubleclick.net" rel="preconnect"/>
#    <link href="https://insights.hotjar.com" rel="dns-prefetch"/>
#    <link href="https://insights.hotjar.com" rel="preconnect"/>
#    <link href="https://lib.onet.pl" rel="dns-prefetch"/>
#    <link href="https://lib.onet.pl" rel="preconnect"/>
#    <link href="https://onesignal.com" rel="dns-prefetch"/>
#    <link href="https://onesignal.com" rel="preconnect"/>
#    <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/>
#    <link href="https://pagead2.googlesyndication.com" rel="preconnect"/>
#    <link href="https://script.hotjar.com" rel="dns-prefetch"/>
#    <link href="https://script.hotjar.com" rel="preconnect"/>
#    <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/>
#    <link href="https://securepubads.g.doubleclick.net" rel="preconnect"/>
#    <link href="https://sgqcvfjvr.onet.pl" rel="dns-prefetch"/>
#    <link href="https://sgqcvfjvr.onet.pl" rel="preconnect"/>
#    <link href="https://static.hotjar.com" rel="dns-prefetch"/>
#    <link href="https://static.hotjar.com" rel="preconnect"/>
#    <link href="https://stats.g.doubleclick.net" rel="dns-prefetch"/>
#    <link href="https://stats.g.doubleclick.net" rel="preconnect"/>
#    <link href="https://tpc.googlesyndication.com" rel="dns-prefetch"/>
#    <link href="https://tpc.googlesyndication.com" rel="preconnect"/>
#    <link href="https://vars.hotjar.com" rel="dns-prefetch"/>
#    <link href="https://vars.hotjar.com" rel="preconnect"/>
#    <link href="https://www.facebook.com" rel="dns-prefetch"/>
#    <link href="https://www.facebook.com" rel="preconnect"/>
#    <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
#    <link href="https://www.google-analytics.com" rel="preconnect"/>
#    <link href="https://www.googleadservices.com" rel="dns-prefetch"/>
#    <link href="https://www.googleadservices.com" rel="preconnect"/>
#    <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#    <link href="https://www.googletagmanager.com" rel="preconnect"/>
#    <link href="https://www.googletagservices.com" rel="dns-prefetch"/>
#    <link href="https://www.googletagservices.com" rel="preconnect"/>
#    <link as="style" href="https://www.pigiame.co.ke/assets/pi-site/css/main.91d1f0f6.css" rel="preload"/>
#    <link as="script" href="https://www.pigiame.co.ke/assets/pi-site/scripts/jquery.min.cf2fbbf8.js" rel="preload"/>
#    <link as="script" href="https://www.pigiame.co.ke/assets/pi-site/scripts/dependencies-modern.min.da508805.js" rel="preload"/>
#    <title>
#     It &amp; Software Jobs in Kenya | PigiaMe
#    </title>
#    <meta content="Find the latest it &amp; software jobs vacancies from top companies and recruiters. Easily apply over WhatsApp, email or phone." name="description"/>
#    <meta content="INDEX, FOLLOW" name="robots"/>
#    <link href="https://www.pigiame.co.ke/it-software-jobs" rel="canonical"/>
#    <meta content="649690445201901" property="fb:app_id"/>
#    <meta content="en_US" property="og:locale"/>
#    <meta content="PigiaMe" property="og:site_name"/>
#    <meta content="IT &amp; Software Jobs in Kenya" property="og:title"/>
#    <meta content="Contact trusted sellers or sign up for alerts." property="og:description"/>
#    <meta content="https://www.pigiame.co.ke/it-software-jobs" property="og:url"/>
#    <meta content="Website" property="og:type"/>
#    <meta content="https://i.roamcdn.net/t/hz/pi/og-template-1200w-630h/84c954b260e78ba2ba80de9160ac2419/-/eyJ0ZW1wbGF0ZSI6ImNhdGVnb3J5IiwicmVwbGFjZW1lbnRzIjp7InRpdGxlMSI6IklUICYgU29mdHdhcmUiLCJ0aXRsZTIiOiIgSm9icyJ9LCJpbWFnZXMiOltdfQ%3D%3D/it-software-jobs.jpg" property="og:image"/>
#    <meta content="1200" property="og:image:width"/>
#    <meta content="630" property="og:image:height"/>
#    <meta content="https://i.roamcdn.net/t/hz/pi/og-template-1080w-1080h/e431d83812b63912c5996ba4268e1ac9/-/eyJ0ZW1wbGF0ZSI6ImNhdGVnb3J5LXNxdWFyZSIsInJlcGxhY2VtZW50cyI6eyJ0aXRsZTEiOiJJVCAmIFNvZnR3YXJlIEpvYnMiLCJ0aXRsZTIiOiIifSwiaW1hZ2VzIjpbXX0%3D/it-software-jobs.jpg" property="og:image"/>
#    <meta content="1080" property="og:image:width"/>
#    <meta content="1080" property="og:image:height"/>
#    <meta content="c-it-software-jobs" name="sailthru.tags"/>
#    <meta content="summary" name="twitter:card"/>
#    <meta content="@PigiaMe" name="twitter:site"/>
#    <link href="https://www.pigiame.co.ke/it-software-jobs?page=2" rel="next"/>
#    <link href="https://www.pigiame.co.ke/assets/pi-site/favicon/favicon.f3937744.ico" rel="shortcut icon" sizes="any"/>
#    <link href="https://www.pigiame.co.ke/assets/pi-site/favicon/favicon.bdeb05e3.svg" rel="icon" type="image/svg+xml"/>
#    <link href="https://www.pigiame.co.ke/assets/pi-site/favicon/apple-touch-icon.a07f08b2.png" rel="apple-touch-icon" sizes="180x180"/>
#    <link href="https://www.pigiame.co.ke/assets/pi-site/favicon/favicon-32x32.11b7dff0.png" rel="icon" sizes="32x32" type="image/png"/>
#    <link href="https://www.pigiame.co.ke/assets/pi-site/favicon/favicon-16x16.eb58a032.png" rel="icon" sizes="16x16" type="image/png"/>
#    <link href="https://www.pigiame.co.ke/assets/pi-site/favicon/site.9243224e.webmanifest" rel="manifest"/>
#    <link color="#ff2727" href="https://www.pigiame.co.ke/assets/pi-site/favicon/safari-pinned-tab.a89e5fae.svg" rel="mask-icon"/>
#    <meta content="PigiaMe" name="apple-mobile-web-app-title"/>
#    <meta content="PigiaMe" name="application-name"/>
#    <meta content="#ff2727" name="msapplication-TileColor"/>
#    <meta content="https://www.pigiame.co.ke/assets/pi-site/favicon/mstile-144x144.7c81abe9.png" name="msapplication-TileImage"/>
#    <meta content="https://www.pigiame.co.ke/assets/pi-site/favicon/browserconfig.dba1a698.xml" name="msapplication-config"/>
#    <meta content="#ff2727" name="theme-color"/>
#    <meta content="U4MqL6l4LyuI9iRV4fVkpHhee8NEzSrE3HHDyf06" name="csrf-token"/>
#    <meta content="_token" name="csrf-param"/>
#    <meta content="00619A2EA4B7B725F327200FCDEC7622" name="msvalidate.01"/>
#    <meta content="Download now to Buy and Sell online" name="smartbanner:title"/>
#    <meta content="https://www.pigiame.co.ke/assets/pi-site/favicon/smart-banner-icon.4baf38cf.png" name="smartbanner:icon"/>
#    <meta content="GET" name="smartbanner:button"/>
#    <meta content="app-id=ke.co.pigiame" name="google-play-app"/>
#    <img height="99999" src="data:image/svg+xml;base64,..." style="pointer-events: none; position: absolute; top: 0; left: 0; width: 99vw; height: 99vh; max-width: 99vw; max-height: 99vh;" width="99999"/>
#    <link href="https://www.pigiame.co.ke/assets/pi-site/css/main.91d1f0f6.css" media="all" rel="stylesheet" type="text/css"/>
#    <script type="text/javascript">
#     !function(o){var e,t,a=o.$LAB,g="UseLocalXHR",h="AlwaysPreserveOrder",m="AllowDuplicates",v="CacheBust",_="BasePath",w=/^[^?#]*\//.exec(location.href)[0],b=/^\w+\:\/\/\/?[^\/]+/.exec(w)[0],S=document.head||document.getElementsByTagName("head"),n=o.opera&&"[object Opera]"==Object.prototype.toString.call(o.opera)||"MozAppearance"in document.documentElement.style,r=document.createElement("script"),x="boolean"==typeof r.preload,A=x||r.readyState&&"uninitialized"==r.readyState,E=!A&&!0===r.async,s=!A&&!E&&!n;function L(e){return"[object Function]"==Object.prototype.toString.call(e)}function O(e){return"[object Array]"==Object.prototype.toString.call(e)}function B(e,t){for(var n in e)e.hasOwnProperty(n)&&(t[n]=e[n]);return t}function Q(e,t,n,r){e.onload=e.onreadystatechange=function(){e.readyState&&"complete"!=e.readyState&&"loaded"!=e.readyState||t[n]||(e.onload=e.onreadystatechange=null,r())}}function C(e){e.ready=e.finished=!0;for(var t=0;t<e.finished_listeners.length;t++)e.finished_listeners[t]();e.ready_listeners=[],e.finished_listeners=[]}o.$LAB=function e(){var r,t={},f=A||s,i=[],p={};function y(o,a,e,t){function n(){a.ready_cb(a,function(){function e(){null!=i&&(i=null,C(r))}var t,n,r,i;t=o,r=s,p[(n=a).src].finished||(t[m]||(p[n.src].finished=!0),i=r.elem||document.createElement("script"),n.type&&(i.type=n.type),n.charset&&(i.charset=n.charset),Q(i,r,"finished",e),r.elem?r.elem=null:r.text?(i.onload=i.onreadystatechange=null,i.text=r.text):i.src=n.real_src,S.insertBefore(i,S.firstChild),r.text&&e())})}function r(){a.finished_cb(a,e)}var s,i,c,l,d,u,f,y,h;a.src=(i=a.src,c=o[_],l=/^\w+\:\/\//,/^\/\/\/?/.test(i)?i=location.protocol+i:l.test(i)||"/"==i.charAt(0)||(i=(c||"")+i),l.test(i)?i:("/"==i.charAt(0)?b:w)+i),a.real_src=a.src+(o[v]?(/\?.*$/.test(a.src)?"&_":"?_")+~~(1e9*Math.random())+"=":""),p[a.src]||(p[a.src]={items:[],finished:!1}),c=p[a.src].items,o[m]||0==c.length?(s=c[c.length]={ready:!1,finished:!1,ready_listeners:[n],finished_listeners:[r]},d=o,u=a,f=s,y=t?function(){s.ready=!0;for(var e=0;e<s.ready_listeners.length;e++)s.ready_listeners[e]();s.ready_listeners=[]}:function(){C(s)},h=t,setTimeout(function(){var e,t,n=u.real_src;if("item"in S){if(!S[0])return void setTimeout(arguments.callee,25);S=S[0]}e=document.createElement("script"),u.type&&(e.type=u.type),u.charset&&(e.charset=u.charset),h?A?(f.elem=e,x?(e.preload=!0,e.onpreload=y):e.onreadystatechange=function(){"loaded"==e.readyState&&y()},e.src=n):h&&0==n.indexOf(b)&&d[g]?((t=new XMLHttpRequest).onreadystatechange=function(){4==t.readyState&&(t.onreadystatechange=function(){},f.text=t.responseText+"\n//@ sourceURL="+n,y())},t.open("GET",n),t.send()):(e.type="text/cache-script",Q(e,f,"ready",function(){S.removeChild(e),y()}),e.src=n,S.insertBefore(e,S.firstChild)):(E&&(e.async=!1),Q(e,f,"finished",y),e.src=n,S.insertBefore(e,S.firstChild))},0)):(s=c[0]).finished?r():s.finished_listeners.push(r)}function n(){var o,a,s=B(t,{}),c=[],e=0,l=!1;function d(e,t){e.ready=!0,e.exec_trigger=t,r()}function u(e,t){e.ready=e.finished=!0,e.exec_trigger=null;for(var n=0;n<t.scripts.length;n++)if(!t.scripts[n].finished)return;t.finished=!0,r()}function r(){for(;e<c.length;)if(L(c[e]))try{c[e++]()}catch(e){}else{if(!c[e].finished){if(function(e){for(var t=!1,n=0;n<e.scripts.length;n++)e.scripts[n].ready&&e.scripts[n].exec_trigger&&(t=!0,e.scripts[n].exec_trigger(),e.scripts[n].exec_trigger=null);return t}(c[e]))continue;break}e++}e==c.length&&(a=l=!1)}return{script:(o={script:function(){for(var e=0;e<arguments.length;e++){i=t=void 0;var t,n=arguments[e],r=arguments[e];O(n)||(r=[n]);for(var i=0;i<r.length;i++)a&&a.scripts||c.push(a={scripts:[],finished:!0}),(n=L(n=r[i])?n():n)&&(O(n)?((t=[].slice.call(n)).unshift(i,1),[].splice.apply(r,t),i--):(n=B(n="string"==typeof n?{src:n}:n,{ready:!1,ready_cb:d,finished:!1,finished_cb:u}),a.finished=!1,a.scripts.push(n),y(s,n,a,f&&l),l=!0,s[h]&&o.wait()))}return o},wait:function(){if(0<arguments.length){for(var e=0;e<arguments.length;e+ ...
#    </script>
#    <script>
#     window.dataLayer = [{"domain_code":"pi","env":"production","route_name":"listings.category","locale":"en","version":"master-2202","service_worker":"service-worker.js","service_worker_updater":"service-worker-updater.js","guest_has_saved_searches":false,"category_slug":"it-software-jobs","category_slugs":"classifieds|jobs|it-software-jobs","dfp_targeting_key":"URL_PigiaMe","dfp_targeting_value":"\/it-software-jobs","pageview_count":1,"session_hash":"fa3f84c9b2b6d62299a79f2216d552b0","request_id":"685661efb32a8b5b494836aeb30c181d","timestamp":1676402882,"url_path":"\/it-software-jobs","url_path_with_query":"\/it-software-jobs","url_path_with_query_without_utm":"\/it-software-jobs","onesignal_url_path":"\/it-software-jobs","ga_optimize_exp":"","experiments_running":"","experiments":[]}];
#    </script>
#    <script>
#     (function(w,d,s,l,i){
#             w[l] = w[l] || [];
#             w[l].push(
#                 {
#                     'gtm.start': new Date().getTime(),
#                     event:'gtm.js'
#                 }
#             );
#             var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s),
#                 dl = l != 'dataLayer'
#                     ? '&l=' + l
#                     : '';
#             j.async = true;
#             j.src = 'https://www.googletagmanager.com/gtm.js?id=' + i + dl;
#             f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-5D5748K');
#    </script>
#   </meta>
#  </head>
#  <body class="category-root--default">
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5D5748K" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <div class="wrap">
#    <ins class="bn bn--970-90 search-bn search-bn--desktop-header">
#     <div class="bn__outer">
#      <a class="bn__inner" data-bn="" data-bn-click="" data-bn-impression="" href="https://www.pigiame.co.ke/company/abizoom-business-machines-ltd#listings" rel="noopener noindex nofollow" target="_blank">
#       <img loading="lazy" src="https://i.roamcdn.net/sdc-bn/default/7e86caaa8fbf4cfd5b8f68b7cf8e64f2/15bd5c785ace1729c818869c1f8a8f94/-/cde-bn-production/client-8/hzwriMTZLKMHTQMRqr3l7vh7pmaTQNMPe1dClkWi.jpg"/>
#      </a>
#     </div>
#    </ins>
#    <header class="header" data-sticky='{"type":"header"}'>
#     <div class="header__inner">
#      <a class="header-logo" href="https://www.pigiame.co.ke">
#       <span class="header-logo__brand">
#        PigiaMe
#       </span>
#       <img alt="PigiaMe" class="header-logo__img" src="https://www.pigiame.co.ke/assets/pi-site/img/logo-colour.31d0bf5a.svg"/>
#      </a>
#      <span class="header-locale-spacer">
#      </span>
#      <span class="header-menu-toggle">
#       <a aria-label="Menu" class="btn header-menu-toggle__button" data-menu-nav-toggle="" href="#">
#        <svg aria-hidden="true" class="i i-menu header-menu-toggle__button-icon">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#menu">
#         </use>
#        </svg>
#       </a>
#      </span>
#      <div class="header-cta">
#       <a class="btn btn-primary header-cta__button" href="https://www.pigiame.co.ke/account/listing/create/listing">
#        <span class="header-cta__button-title">
#         Sell
#        </span>
#       </a>
#      </div>
#      <div class="header__buttons-section ">
#       <div class="header-auth">
#        <a class="btn btn-default header-auth__item" href="https://www.pigiame.co.ke/account/login">
#         Login / Register
#        </a>
#       </div>
#      </div>
#      <div class="global-search">
#       <div class="global-search__inner">
#        <form accept-charset="UTF-8" action="https://www.pigiame.co.ke/classifieds" class="global-search__form" method="GET">
#         <div class="global-search__query">
#          <label class="sr-only" for="q">
#           Text Search or ID (e.g. "id:123456")
#          </label>
#          <input class="form-control autocomplete global-search__query-input" data-autocomplete='{"appendTo":".global-search__inner"}' data-url="https://www.pigiame.co.ke/ajax/suggestions?is_business=0" id="q" name="q" placeholder="I'm looking for..." type="text"/>
#          <svg aria-hidden="true" class="i i-magnify global-search__query-icon">
#           <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#magnify">
#           </use>
#          </svg>
#         </div>
#         <button class="btn global-search__button" type="submit">
#          <svg aria-hidden="true" class="i i-magnify global-search__button__icon">
#           <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#magnify">
#           </use>
#          </svg>
#          <span hidden="">
#           Search
#          </span>
#         </button>
#        </form>
#       </div>
#      </div>
#     </div>
#    </header>
#    <nav class="header-nav" data-header-nav="">
#     <div class="header-nav__inner-container">
#      <ul class="header-nav__inner">
#       <li class="header-nav__inner__item">
#        <a class="header-nav__inner__item__link" href="https://www.pigiame.co.ke/electronics">
#         Electronics
#        </a>
#       </li>
#       <li class="header-nav__inner__item">
#        <a class="header-nav__inner__item__link" href="https://www.pigiame.co.ke/home-garden-kids">
#         Home, Garden &amp; Kids
#        </a>
#       </li>
#       <li class="header-nav__inner__item">
#        <a class="header-nav__inner__item__link" href="https://www.pigiame.co.ke/c-vehicles">
#         Vehicles
#        </a>
#       </li>
#       <li class="header-nav__inner__item">
#        <a class="header-nav__inner__item__link" href="https://www.pigiame.co.ke/car-parts-accessories">
#         Car Parts &amp; Accessories
#        </a>
#       </li>
#       <li class="header-nav__inner__item">
#        <a class="header-nav__inner__item__link" href="https://www.pigiame.co.ke/property-rentals-sales">
#         Property Rentals &amp; Sales
#        </a>
#       </li>
#      </ul>
#      <ul class="header-nav__inner__right">
#       <li class="header-nav__inner__item header-nav__inner__item--all">
#        <a class="header-nav__inner__item__link" href="https://www.pigiame.co.ke/classifieds">
#         <svg aria-hidden="true" class="i i-categories header-nav__inner__item__category-icon">
#          <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#categories">
#          </use>
#         </svg>
#         Other Categories
#        </a>
#       </li>
#       <li class="header-nav__inner__item header-nav__inner__item--businesses">
#        <a class="header-nav__inner__item__link header-nav__inner__item__link--businesses" href="https://www.pigiame.co.ke/shops">
#         <svg aria-hidden="true" class="i i-briefcase header-nav__inner__item__category-icon">
#          <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#briefcase">
#          </use>
#         </svg>
#         Exclusive Shops
#        </a>
#       </li>
#       <li class="header-nav__inner__item header-nav__inner__item--businesses">
#        <a class="header-nav__inner__item__link header-nav__inner__item__link--deals" href="https://www.pigiame.co.ke/deals">
#         <svg aria-hidden="true" class="i i-handshake header-nav__inner__item__category-icon">
#          <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#handshake">
#          </use>
#         </svg>
#         Deals
#        </a>
#       </li>
#      </ul>
#     </div>
#    </nav>
#    <ins class="bn bn--320-50 search-bn search-bn--mobile-top">
#     <div class="bn__outer">
#      <a class="bn__inner" data-bn="" data-bn-click="" data-bn-impression="" href="https://www.pigiame.co.ke/company/etech-office-solutions#listings" rel="noopener noindex nofollow" target="_blank">
#       <img loading="lazy" src="https://i.roamcdn.net/sdc-bn/default/e3858a108f45d640f7048ebadff3bbd4/1ac7d126b7ec3c6e800a615e83d08150/-/cde-bn-production/client-8/pCiNuEQpMi051mzzbSUTTRMfPkk74Vq8o1YoF3P9.jpg"/>
#      </a>
#     </div>
#    </ins>
#    <div class="search">
#     <div class="search__container">
#      <div class="search__row">
#       <div class="search__content-row-container">
#        <div class="search__content-row">
#         <div class="search__content">
#          <div id="listings">
#           <div class="listings-header">
#            <div class="listings-header__inner">
#             <div class="listings-header__nav">
#              <div class="listings-header-breadcrumbs">
#               <div class="breadcrumbs" data-cy="breadcrumbs">
#                <ul class="breadcrumbs__list">
#                 <li class="breadcrumbs__list-item">
#                  <a class="breadcrumbs__list-item__link" href="https://www.pigiame.co.ke">
#                   Home
#                  </a>
#                 </li>
#                 <li class="breadcrumbs__list-item" id="breadcrumbs-category-classifieds">
#                  <a class="breadcrumbs__list-item__link" href="https://www.pigiame.co.ke/classifieds">
#                   Classifieds
#                  </a>
#                 </li>
#                 <li class="breadcrumbs__list-item" id="breadcrumbs-category-jobs">
#                  <a class="breadcrumbs__list-item__link" href="https://www.pigiame.co.ke/jobs">
#                   Jobs
#                  </a>
#                 </li>
#                 <li class="breadcrumbs__list-item" id="breadcrumbs-category-it-software-jobs">
#                  <a class="breadcrumbs__list-item__link" href="https://www.pigiame.co.ke/it-software-jobs">
#                   IT &amp; Software Jobs
#                  </a>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#             <div class="listings-header__filter-tags">
#             </div>
#             <div class="listings-header__title">
#              <div class="listings-header-title">
#               <h1 class="listings-header-title__title">
#                It &amp; software jobs in Kenya
#               </h1>
#               <span class="listings-header-title__count">
#                42 results found
#               </span>
#              </div>
#              <div class="listings-header-refine-search">
#               <a class="btn btn-primary btn-sm listings-header-refine-search__button" data-search-filter-toggle="" href="#filters">
#                <svg aria-hidden="true" class="i i-filter ">
#                 <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#filter">
#                 </use>
#                </svg>
#                Filter
#               </a>
#              </div>
#              <div class="listings-header-alert listings-header-alert--guest">
#               <span class="btn btn-sm btn-primary listings-header-alert__button" data-alert-form-toggle="">
#                <svg aria-hidden="true" class="i i-email ">
#                 <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#email">
#                 </use>
#                </svg>
#                Save Your Search
#               </span>
#              </div>
#             </div>
#             <div class="listings-header-alert-form" data-alert-form="">
#              <form accept-charset="UTF-8" action="https://www.pigiame.co.ke/saved-searches/store" class="listings-header-alert-form__inner" data-form-blocking="" data-t-saved_search="" data-validate-form="" method="POST">
#               <input name="_token" type="hidden"/>
#               <input name="redirect" type="hidden" value="https://www.pigiame.co.ke/it-software-jobs"/>
#               <input name="s" type="hidden" value="ea8eb877b3a29f2ba43f771cb94faeb9"/>
#               <input name="title" type="hidden" value="It &amp; software jobs in Kenya"/>
#               <div class="listings-header-alert-form__email">
#                <label class="sr-only" for="email">
#                 Email
#                </label>
#                <input autocomplete="email" class="form-control" id="email" name="email" placeholder="Email" required="" type="email"/>
#                <div class="errors">
#                </div>
#               </div>
#               <div class="listings-header-alert-form__submit">
#                <button class="btn btn-primary btn-block listings-header-alert-form__button" id="create-alert" type="submit">
#                 Subscribe
#                </button>
#               </div>
#              </form>
#             </div>
#            </div>
#           </div>
#          </div>
#          <div class="listings-cards">
#           <div class="listings-cards__list">
#            <div class="listings-cards__list-item ">
#             <div class="listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder">
#              <a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="it-software-jobs" data-t-listing_category_title="IT &amp; Software Jobs" data-t-listing_context="search" data-t-listing_currency="" data-t-listing_id="5478002" data-t-listing_location_title="Nairobi CBD" data-t-listing_price="0" data-t-listing_product_slugs="listing" data-t-listing_slug="software-developer" data-t-listing_source="bm_ke" data-t-listing_title="Software Developer" data-t-listing_type="classified" href="https://www.pigiame.co.ke/listings/software-developer-5478002" id="listing-5478002">
#               <div class="listing-card__aside">
#                <div class="listing-card__image">
#                 <div class="listing-card__image__inner-container">
#                  <svg aria-hidden="true" class="i i-jobs listing-card__image__placeholder">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#jobs">
#                   </use>
#                  </svg>
#                  <svg aria-hidden="true" class="i i-bm_ke listing-card__image__placeholder listing-card__image__placeholder--scs">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/scs.5429fd6d.svg#bm_ke">
#                   </use>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#               <div class="listing-card__content 1">
#                <div class="listing-card__content__inner">
#                 <div class="listing-card__header">
#                  <div class="listing-card__header-content">
#                   <div class="listing-card__header__title">
#                    Software Developer
#                   </div>
#                   <div class="listing-card__header__tags">
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--work-type listing-card__header__tags__item--work-type_full-time">
#                     Full time
#                    </span>
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--employer listing-card__header__tags__item--employer_aga-khan-health-services">
#                     Aga Khan Health Services
#                    </span>
#                   </div>
#                   <div class="listing-card__header__location">
#                    <svg aria-hidden="true" class="i i-gmaps ">
#                     <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#gmaps">
#                     </use>
#                    </svg>
#                    Nairobi CBD,
# Nairobi
#                   </div>
#                  </div>
#                  <img alt="BrighterMonday" class="scs-logo" loading="lazy" src="https://www.pigiame.co.ke/assets/pi-site/img/sources/bm_ke_sm.2a5ebe32.svg"/>
#                 </div>
#                 <div class="listing-card__date-line">
#                  <div class="listing-card__header__date">
#                   Yesterday, 08:47
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#            <div class="listings-cards__list-item ">
#             <div class="listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder">
#              <a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="it-software-jobs" data-t-listing_category_title="IT &amp; Software Jobs" data-t-listing_context="search" data-t-listing_currency="" data-t-listing_id="5474653" data-t-listing_location_title="Other" data-t-listing_price="0" data-t-listing_product_slugs="listing" data-t-listing_slug="software-development-java-nodejs-onsite-nyeri-entry-level" data-t-listing_source="bm_ke" data-t-listing_title="Software Development Java, nodeJs (Onsite Nyeri) entry level" data-t-listing_type="classified" href="https://www.pigiame.co.ke/listings/software-development-java-nodejs-onsite-nyeri-entry-level-5474653" id="listing-5474653">
#               <div class="listing-card__aside">
#                <div class="listing-card__image">
#                 <div class="listing-card__image__inner-container">
#                  <svg aria-hidden="true" class="i i-jobs listing-card__image__placeholder">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#jobs">
#                   </use>
#                  </svg>
#                  <svg aria-hidden="true" class="i i-bm_ke listing-card__image__placeholder listing-card__image__placeholder--scs">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/scs.5429fd6d.svg#bm_ke">
#                   </use>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#               <div class="listing-card__content 1">
#                <div class="listing-card__content__inner">
#                 <div class="listing-card__header">
#                  <div class="listing-card__header-content">
#                   <div class="listing-card__header__title">
#                    Software Development Java, nodeJs (Onsite Nyeri) entry level
#                   </div>
#                   <div class="listing-card__header__tags">
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--work-type listing-card__header__tags__item--work-type_contract">
#                     Contract
#                    </span>
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--employer listing-card__header__tags__item--employer_supreme">
#                     Supreme
#                    </span>
#                   </div>
#                   <div class="listing-card__header__location">
#                    <svg aria-hidden="true" class="i i-gmaps ">
#                     <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#gmaps">
#                     </use>
#                    </svg>
#                    Other,
# Mombasa
#                   </div>
#                  </div>
#                  <img alt="BrighterMonday" class="scs-logo" loading="lazy" src="https://www.pigiame.co.ke/assets/pi-site/img/sources/bm_ke_sm.2a5ebe32.svg"/>
#                 </div>
#                 <div class="listing-card__date-line">
#                  <div class="listing-card__header__date">
#                   Saturday, 10:27
#                  </div>
#                 </div>
#                 <div class="listing-card__info-bar">
#                  <div class="listing-card__info-bar__price">
#                   <span class="listing-card__price">
#                    <span class="listing-card__price__value 1">
#                     KES 45,001 - KES 60,000
#                    </span>
#                   </span>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#            <div class="listings-cards__list-item ">
#             <div class="listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder">
#              <a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="it-software-jobs" data-t-listing_category_title="IT &amp; Software Jobs" data-t-listing_context="search" data-t-listing_currency="" data-t-listing_id="5473981" data-t-listing_location_title="Nairobi CBD" data-t-listing_price="0" data-t-listing_product_slugs="listing" data-t-listing_slug="frontend-developer-reframe" data-t-listing_source="bm_ke" data-t-listing_title="Frontend Developer Reframe" data-t-listing_type="classified" href="https://www.pigiame.co.ke/listings/frontend-developer-reframe-5473981" id="listing-5473981">
#               <div class="listing-card__aside">
#                <div class="listing-card__image">
#                 <div class="listing-card__image__inner-container">
#                  <svg aria-hidden="true" class="i i-jobs listing-card__image__placeholder">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#jobs">
#                   </use>
#                  </svg>
#                  <svg aria-hidden="true" class="i i-bm_ke listing-card__image__placeholder listing-card__image__placeholder--scs">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/scs.5429fd6d.svg#bm_ke">
#                   </use>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#               <div class="listing-card__content 1">
#                <div class="listing-card__content__inner">
#                 <div class="listing-card__header">
#                  <div class="listing-card__header-content">
#                   <div class="listing-card__header__title">
#                    Frontend Developer Reframe
#                   </div>
#                   <div class="listing-card__header__tags">
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--work-type listing-card__header__tags__item--work-type_full-time">
#                     Full time
#                    </span>
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--employer listing-card__header__tags__item--employer_cohere">
#                     Cohere
#                    </span>
#                   </div>
#                   <div class="listing-card__header__location">
#                    <svg aria-hidden="true" class="i i-gmaps ">
#                     <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#gmaps">
#                     </use>
#                    </svg>
#                    Nairobi CBD,
# Nairobi
#                   </div>
#                  </div>
#                  <img alt="BrighterMonday" class="scs-logo" loading="lazy" src="https://www.pigiame.co.ke/assets/pi-site/img/sources/bm_ke_sm.2a5ebe32.svg"/>
#                 </div>
#                 <div class="listing-card__date-line">
#                  <div class="listing-card__header__date">
#                   Friday, 16:49
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#            <div class="listings-cards__list-item ">
#             <div class="listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder">
#              <a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="it-software-jobs" data-t-listing_category_title="IT &amp; Software Jobs" data-t-listing_context="search" data-t-listing_currency="" data-t-listing_id="5472628" data-t-listing_location_title="Nairobi CBD" data-t-listing_price="0" data-t-listing_product_slugs="listing" data-t-listing_slug="chatbot-developer" data-t-listing_source="bm_ke" data-t-listing_title="Chatbot Developer" data-t-listing_type="classified" href="https://www.pigiame.co.ke/listings/chatbot-developer-5472628" id="listing-5472628">
#               <div class="listing-card__aside">
#                <div class="listing-card__image">
#                 <div class="listing-card__image__inner-container">
#                  <svg aria-hidden="true" class="i i-jobs listing-card__image__placeholder">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#jobs">
#                   </use>
#                  </svg>
#                  <svg aria-hidden="true" class="i i-bm_ke listing-card__image__placeholder listing-card__image__placeholder--scs">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/scs.5429fd6d.svg#bm_ke">
#                   </use>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#               <div class="listing-card__content 1">
#                <div class="listing-card__content__inner">
#                 <div class="listing-card__header">
#                  <div class="listing-card__header-content">
#                   <div class="listing-card__header__title">
#                    Chatbot Developer
#                   </div>
#                   <div class="listing-card__header__tags">
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--work-type listing-card__header__tags__item--work-type_full-time">
#                     Full time
#                    </span>
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--employer listing-card__header__tags__item--employer_sos-childrens-villages-international">
#                     SOS Children's Villages International
#                    </span>
#                   </div>
#                   <div class="listing-card__header__location">
#                    <svg aria-hidden="true" class="i i-gmaps ">
#                     <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#gmaps">
#                     </use>
#                    </svg>
#                    Nairobi CBD,
# Nairobi
#                   </div>
#                  </div>
#                  <img alt="BrighterMonday" class="scs-logo" loading="lazy" src="https://www.pigiame.co.ke/assets/pi-site/img/sources/bm_ke_sm.2a5ebe32.svg"/>
#                 </div>
#                 <div class="listing-card__date-line">
#                  <div class="listing-card__header__date">
#                   Friday, 09:06
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#            <div class="listings-cards__list-item ">
#             <div class="listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder">
#              <a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="it-software-jobs" data-t-listing_category_title="IT &amp; Software Jobs" data-t-listing_context="search" data-t-listing_currency="" data-t-listing_id="5471542" data-t-listing_location_title="Nairobi CBD" data-t-listing_price="0" data-t-listing_product_slugs="listing" data-t-listing_slug="assistant-it-administrator" data-t-listing_source="bm_ke" data-t-listing_title="Assistant IT Administrator" data-t-listing_type="classified" href="https://www.pigiame.co.ke/listings/assistant-it-administrator-5471542" id="listing-5471542">
#               <div class="listing-card__aside">
#                <div class="listing-card__image">
#                 <div class="listing-card__image__inner-container">
#                  <svg aria-hidden="true" class="i i-jobs listing-card__image__placeholder">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#jobs">
#                   </use>
#                  </svg>
#                  <svg aria-hidden="true" class="i i-bm_ke listing-card__image__placeholder listing-card__image__placeholder--scs">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/scs.5429fd6d.svg#bm_ke">
#                   </use>
#                  </svg>
#                  <div class="listing-card__image__inner">
#                   <img alt="Assistant IT Administrator" class="listing-card__image__resource vh-img" loading="lazy" src="https://i.roamcdn.net/hz/pi/listing-thumb-112w/a914b1ce66308ff21df68464993a4476/-/horizon-files-prod/pi/picture/qennp442/3a177b7b8c47ecfc8c84b85831405bb3f7c367a1.jpg" srcset="https://i.roamcdn.net/hz/pi/listing-thumb-112w/a914b1ce66308ff21df68464993a4476/-/horizon-files-prod/pi/picture/qennp442/3a177b7b8c47ecfc8c84b85831405bb3f7c367a1.jpg 112w,https://i.roamcdn.net/hz/pi/listing-thumb-224w/31a3aa5f536353affa01b63728b78ce6/-/horizon-files-prod/pi/picture/qennp442/3a177b7b8c47ecfc8c84b85831405bb3f7c367a1.jpg 224w,https://i.roamcdn.net/hz/pi/listing-thumb-180w/b16ed9fa9f0e5f4726c2b53b83aea4c6/-/horizon-files-prod/pi/picture/qennp442/3a177b7b8c47ecfc8c84b85831405bb3f7c367a1.jpg 180w,https://i.roamcdn.net/hz/pi/listing-thumb-360w/2a2e646b33f113bef1f39df5f7473ab9/-/horizon-files-prod/pi/picture/qennp442/3a177b7b8c47ecfc8c84b85831405bb3f7c367a1.jpg 337w"/>
#                  </div>
#                 </div>
#                </div>
#               </div>
#               <div class="listing-card__content 1">
#                <div class="listing-card__content__inner">
#                 <div class="listing-card__header">
#                  <div class="listing-card__header-content">
#                   <div class="listing-card__header__title">
#                    Assistant IT Administrator
#                   </div>
#                   <div class="listing-card__header__tags">
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--work-type listing-card__header__tags__item--work-type_full-time">
#                     Full time
#                    </span>
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--employer listing-card__header__tags__item--employer_bidwood-suite-hotel">
#                     Bidwood Suite Hotel
#                    </span>
#                   </div>
#                   <div class="listing-card__header__location">
#                    <svg aria-hidden="true" class="i i-gmaps ">
#                     <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#gmaps">
#                     </use>
#                    </svg>
#                    Nairobi CBD,
# Nairobi
#                   </div>
#                  </div>
#                  <img alt="BrighterMonday" class="scs-logo" loading="lazy" src="https://www.pigiame.co.ke/assets/pi-site/img/sources/bm_ke_sm.2a5ebe32.svg"/>
#                 </div>
#                 <div class="listing-card__date-line">
#                  <div class="listing-card__header__date">
#                   Thursday, 17:19
#                  </div>
#                 </div>
#                 <div class="listing-card__info-bar">
#                  <div class="listing-card__info-bar__price">
#                   <span class="listing-card__price">
#                    <span class="listing-card__price__value 1">
#                     KES 15,001 - KES 30,000
#                    </span>
#                   </span>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#            <ins class="bn bn--728-90 search-bn search-bn--desktop-middle">
#             <div class="bn__outer">
#              <a class="bn__inner" data-bn="" data-bn-click="" data-bn-click-action="clicks" data-bn-click-category="search_desktop_middle" data-bn-click-label="orthodynamic" data-bn-impression="" data-bn-impression-action="impressions" data-bn-impression-category="search_desktop_middle" data-bn-impression-label="orthodynamic" href="https://www.orthodyna.com/shop/" rel="noopener noindex nofollow" target="_blank">
#               <img loading="lazy" src="https://i.roamcdn.net/sdc-bn/default/58317cd236f36059667cd6d7adf4ef45/f484ae643e1c54659125480151450438/-/cde-bn-production/client-8/dktG5vtGuhSKcgMK2qv40FitL6xJ1l8FhmksVBKB.jpg"/>
#              </a>
#             </div>
#            </ins>
#            <ins class="bn bn--300-250 search-bn search-bn--mobile-middle">
#             <div class="bn__outer">
#              <a class="bn__inner" data-bn="" data-bn-click="" data-bn-click-action="clicks" data-bn-click-category="search_mobile_middle" data-bn-click-label="orthodynamic" data-bn-impression="" data-bn-impression-action="impressions" data-bn-impression-category="search_mobile_middle" data-bn-impression-label="orthodynamic" href="https://www.orthodyna.com/" rel="noopener noindex nofollow" target="_blank">
#               <img loading="lazy" src="https://i.roamcdn.net/sdc-bn/default/bd18abf564dfa38c398546282bfa0b94/9b8658caa5b102d24a6f9f4949b805b5/-/cde-bn-production/client-8/kkP9HepAHKyR7NTMxyyChHkrtgaDVdzFtlQNCk0Y.jpg"/>
#              </a>
#             </div>
#            </ins>
#            <a class="listings-cards__list-item listings-cards__list-item--sell-everything" href="https://www.pigiame.co.ke/account/listing/create/listing">
#             <div class="sell-everything-card">
#              <img alt="Uza chap chap!" class="sell-everything-card__img sell-everything-card__img--desktop" height="200" loading="lazy" src="https://www.pigiame.co.ke/assets/pi-site/img/static/everything-card-desktop.4eb7627a.jpg" width="752"/>
#              <img alt="Uza chap chap!" class="sell-everything-card__img sell-everything-card__img--mobile" height="400" loading="lazy" src="https://www.pigiame.co.ke/assets/pi-site/img/static/everything-card-mobile.87d64c1d.jpg" width="296"/>
#             </div>
#            </a>
#            <div class="listings-cards__list-item ">
#             <div class="listing-card listing-card--tab listing-card--has-content listing-card--highlight-placeholder">
#              <a class="listing-card__inner" data-t-listing="" data-t-listing_category_slug="it-software-jobs" data-t-listing_category_title="IT &amp; Software Jobs" data-t-listing_context="search" data-t-listing_currency="" data-t-listing_id="5471441" data-t-listing_location_title="Nairobi CBD" data-t-listing_price="0" data-t-listing_product_slugs="listing" data-t-listing_slug="frontend-developer" data-t-listing_source="bm_ke" data-t-listing_title="Frontend Developer" data-t-listing_type="classified" href="https://www.pigiame.co.ke/listings/frontend-developer-5471441" id="listing-5471441">
#               <div class="listing-card__aside">
#                <div class="listing-card__image">
#                 <div class="listing-card__image__inner-container">
#                  <svg aria-hidden="true" class="i i-jobs listing-card__image__placeholder">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#jobs">
#                   </use>
#                  </svg>
#                  <svg aria-hidden="true" class="i i-bm_ke listing-card__image__placeholder listing-card__image__placeholder--scs">
#                   <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/scs.5429fd6d.svg#bm_ke">
#                   </use>
#                  </svg>
#                 </div>
#                </div>
#               </div>
#               <div class="listing-card__content 1">
#                <div class="listing-card__content__inner">
#                 <div class="listing-card__header">
#                  <div class="listing-card__header-content">
#                   <div class="listing-card__header__title">
#                    Frontend Developer
#                   </div>
#                   <div class="listing-card__header__tags">
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--work-type listing-card__header__tags__item--work-type_full-time">
#                     Full time
#                    </span>
#                    <span class="listing-card__header__tags__item listing-card__header__tags__item--employer listing-card__header__tags__item--employer_safaricom">
#                     Safaricom
#                    </span>
#                   </div>
#                   <div class="listing-card__header__location">
#                    <svg aria-hidden="true" class="i i-gmaps ">
#                     <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#gmaps">
#                     </use>
#                    </svg>
#                    Nairobi CBD,
# Nairobi
#                   </div>
#                  </div>
#                  <img alt="BrighterMonday" class="scs-logo" loading="lazy" src="https://www.pigiame.co.ke/assets/pi-site/img/sources/bm_ke_sm.2a5ebe32.svg"/>
#                 </div>
#                 <div class="listing-card__date-line">
#                  <div class="listing-card__header__date">
#                   Thursday, 16:37
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </a>
#             </div>
#            </div>
#            <div class="listings-cards__list-item ">
# ...
#            Follow PigiaMe on LinkedIn
#           </span>
#          </a>
#         </li>
#         <li class="footer-links__list-social-item">
#          <a class="ic ic--pinterest footer-links__list-social-item__network footer-links__list-social-item__network--pinterest" href="https://www.pinterest.com/pigiame/" rel="noopener nofollow" target="_blank">
#           <svg aria-hidden="true" class="i i-pinterest ">
#            <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#pinterest">
#            </use>
#           </svg>
#           <span class="footer-links__list-social-item__network-title">
#            Follow PigiaMe on Pinterest
#           </span>
#          </a>
#         </li>
#         <li class="footer-links__list-social-item">
#          <a class="ic ic--youtube footer-links__list-social-item__network footer-links__list-social-item__network--youtube" href="https://www.youtube.com/channel/UCzVJRy0eB_NNXM3wj-cA6fQ" rel="noopener nofollow" target="_blank">
#           <svg aria-hidden="true" class="i i-youtube ">
#            <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#youtube">
#            </use>
#           </svg>
#           <span class="footer-links__list-social-item__network-title">
#            Follow PigiaMe on YouTube
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="footer-copyright">
#      <div class="footer-copyright__container">
#       <div class="footer-copyright__inner">
#        <div class="footer-copyright__notice">
#         Copyright © 2016-2023 PigiaMe
#        </div>
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <nav class="menu-nav">
#    <div class="menu-nav__inner">
#     <div class="menu-nav__header">
#      <span class="menu-nav-toggle">
#       <a class="btn menu-nav-toggle__button" data-menu-nav-toggle="" href="#">
#        <svg aria-hidden="true" class="i i-close menu-nav-toggle__button-icon">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#close">
#         </use>
#        </svg>
#       </a>
#      </span>
#     </div>
#     <ul class="menu-nav__list">
#      <li class="menu-nav__list-item">
#       <div class="menu-nav__list-item__header">
#        My Profile
#       </div>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link" href="https://www.pigiame.co.ke/account/login">
#        Login / Register
#       </a>
#      </li>
#      <hr class="menu-nav__list-item__divider"/>
#      <li class="menu-nav__list-item">
#       <div class="menu-nav__list-item__header">
#        Categories
#       </div>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/shops">
#        <svg aria-hidden="true" class="i i-briefcase ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#briefcase">
#         </use>
#        </svg>
#        Exclusive Shops
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link" href="https://www.pigiame.co.ke">
#        <svg aria-hidden="true" class="i i-account ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg#account">
#         </use>
#        </svg>
#        Classifieds
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/building-supplies">
#        <svg aria-hidden="true" class="i i-property-for-rent ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#property-for-rent">
#         </use>
#        </svg>
#        Building Supplies
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/car-parts-accessories">
#        <svg aria-hidden="true" class="i i-car-parts ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#car-parts">
#         </use>
#        </svg>
#        Car Parts &amp; Accessories
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/commercial-supplies">
#        <svg aria-hidden="true" class="i i-instructions-classes ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#instructions-classes">
#         </use>
#        </svg>
#        Commercial Supplies
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/electronics">
#        <svg aria-hidden="true" class="i i-electronics ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#electronics">
#         </use>
#        </svg>
#        Electronics
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/entertainment-sports-travel">
#        <svg aria-hidden="true" class="i i-wellness ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#wellness">
#         </use>
#        </svg>
#        Entertainment, Sports &amp; Travel
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/fashion-beauty">
#        <svg aria-hidden="true" class="i i-fashion ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#fashion">
#         </use>
#        </svg>
#        Fashion &amp; Beauty
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/home-garden-kids">
#        <svg aria-hidden="true" class="i i-home-living ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#home-living">
#         </use>
#        </svg>
#        Home, Garden &amp; Kids
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link active" href="https://www.pigiame.co.ke/jobs">
#        <svg aria-hidden="true" class="i i-jobs ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#jobs">
#         </use>
#        </svg>
#        Jobs
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/property-rentals-sales">
#        <svg aria-hidden="true" class="i i-property-for-sale ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#property-for-sale">
#         </use>
#        </svg>
#        Property Rentals &amp; Sales
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/services">
#        <svg aria-hidden="true" class="i i-professional-services ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#professional-services">
#         </use>
#        </svg>
#        Services
#       </a>
#      </li>
#      <li class="menu-nav__list-item">
#       <a class="menu-nav__list-item__link " href="https://www.pigiame.co.ke/c-vehicles">
#        <svg aria-hidden="true" class="i i-vehicles ">
#         <use xlink:href="https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg#vehicles">
#         </use>
#        </svg>
#        Vehicles
#       </a>
#      </li>
#     </ul>
#    </div>
#   </nav>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.pigiame.co.ke","name":"Home","url":"https://www.pigiame.co.ke"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.pigiame.co.ke/classifieds","name":"Classifieds","url":"https://www.pigiame.co.ke/classifieds"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.pigiame.co.ke/jobs","name":"Jobs","url":"https://www.pigiame.co.ke/jobs"}},{"@type":"ListItem","position":4,"item":{"@id":"https://www.pigiame.co.ke/it-software-jobs","name":"IT & Software Jobs","url":"https://www.pigiame.co.ke/it-software-jobs"}}]}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.pigiame.co.ke/listings/software-developer-5478002","name":"Software Developer","url":"https://www.pigiame.co.ke/listings/software-developer-5478002"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.pigiame.co.ke/listings/software-development-java-nodejs-onsite-nyeri-entry-level-5474653","name":"Software Development Java, nodeJs (Onsite Nyeri) entry level","url":"https://www.pigiame.co.ke/listings/software-development-java-nodejs-onsite-nyeri-entry-level-5474653"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.pigiame.co.ke/listings/frontend-developer-reframe-5473981","name":"Frontend Developer Reframe","url":"https://www.pigiame.co.ke/listings/frontend-developer-reframe-5473981"}},{"@type":"ListItem","position":4,"item":{"@id":"https://www.pigiame.co.ke/listings/chatbot-developer-5472628","name":"Chatbot Developer","url":"https://www.pigiame.co.ke/listings/chatbot-developer-5472628"}},{"@type":"ListItem","position":5,"item":{"@id":"https://www.pigiame.co.ke/listings/assistant-it-administrator-5471542","name":"Assistant IT Administrator","url":"https://www.pigiame.co.ke/listings/assistant-it-administrator-5471542"}},{"@type":"ListItem","position":6,"item":{"@id":"https://www.pigiame.co.ke/listings/frontend-developer-5471441","name":"Frontend Developer","url":"https://www.pigiame.co.ke/listings/frontend-developer-5471441"}},{"@type":"ListItem","position":7,"item":{"@id":"https://www.pigiame.co.ke/listings/crm-enginee-5471294","name":"CRM Enginee","url":"https://www.pigiame.co.ke/listings/crm-enginee-5471294"}},{"@type":"ListItem","position":8,"item":{"@id":"https://www.pigiame.co.ke/listings/analyst-programmer-5469047","name":"Analyst Programmer","url":"https://www.pigiame.co.ke/listings/analyst-programmer-5469047"}},{"@type":"ListItem","position":9,"item":{"@id":"https://www.pigiame.co.ke/listings/senior-game-developer-5468130","name":"Senior Game Developer","url":"https://www.pigiame.co.ke/listings/senior-game-developer-5468130"}},{"@type":"ListItem","position":10,"item":{"@id":"https://www.pigiame.co.ke/listings/lead-full-stack-engineer-5467710","name":"Lead Full Stack Engineer","url":"https://www.pigiame.co.ke/listings/lead-full-stack-engineer-5467710"}}]}
#   </script>
#   <script type="application/ld+json">
#    [{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Electronics","url":"https://www.pigiame.co.ke/electronics"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Home, Garden & Kids","url":"https://www.pigiame.co.ke/home-garden-kids"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Fashion & Beauty","url":"https://www.pigiame.co.ke/fashion-beauty"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Property Rentals & Sales","url":"https://www.pigiame.co.ke/property-rentals-sales"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Vehicles","url":"https://www.pigiame.co.ke/vehicles"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Services","url":"https://www.pigiame.co.ke/services"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Commercial Supplies","url":"https://www.pigiame.co.ke/commercial-supplies"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Building Supplies","url":"https://www.pigiame.co.ke/building-supplies"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Car Parts & Accessories","url":"https://www.pigiame.co.ke/car-parts-accessories"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Entertainment, Sports & Travel","url":"https://www.pigiame.co.ke/entertainment-sports-travel"},{"@context":"http://schema.org","@type":"SiteNavigationElement","name":"Jobs","url":"https://www.pigiame.co.ke/jobs"}]
#   </script>
#   <div class="modal-workflow modal" id="modal-view" role="dialog" tabindex="-1">
#    <div class="modal-dialog" role="document">
#     <div class="modal-content">
#      <div class="modal-header">
#       <div class="modal-title">
#        Title
#       </div>
#      </div>
#      <div class="modal-body">
#       Body
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="backdrop">
#   </div>
#   <div class="backdrop-transition">
#   </div>
#   <script>
#    OAM.scripts = {
#         'jquery': 'https://www.pigiame.co.ke/assets/pi-site/scripts/jquery.min.cf2fbbf8.js',
#         'notify': 'https://www.pigiame.co.ke/assets/pi-site/scripts/notify.min.84816396.js',
#         'slider': 'https://www.pigiame.co.ke/assets/pi-site/scripts/slider.min.18b6dc45.js',
#         'toggle': 'https://www.pigiame.co.ke/assets/pi-site/scripts/toggle.min.adc02a12.js'
#     };
#
#     OAM.styles = {
#         'datepicker': 'https://www.pigiame.co.ke/assets/pi-site/css/datepicker.072a3f33.css',
#         'fileUpload': 'https://www.pigiame.co.ke/assets/pi-site/css/file-upload.9f07c603.css',
#         'notify': 'https://www.pigiame.co.ke/assets/pi-site/css/notify.3571aee9.css',
#         'pagedown': 'https://www.pigiame.co.ke/assets/pi-site/css/pagedown.a3920eb7.css',
#         'smartbanner': 'https://www.pigiame.co.ke/assets/pi-site/css/smartbanner.05022d01.css'
#     };
#
#     OAM.svgs = {
#         'map': 'https://www.pigiame.co.ke/assets/pi-site/icons/map.caece3cf.svg',
#         'category': 'https://www.pigiame.co.ke/assets/pi-site/icons/category.ebab0c24.svg',
#         'scs': 'https://www.pigiame.co.ke/assets/pi-site/icons/scs.5429fd6d.svg'
#     };
#
#     OAM.fonts = ["Roboto","Montserrat"];
#
#     OAM
#         .script(OAM.scripts.jquery).wait()
#         .script("/assets/pi-site/scripts/dependencies-modern.min.da508805.js")
#         .wait(OAM.processReadyQueue);
#
#
#
#
#
#     OAM.script("https://www.pigiame.co.ke/assets/pi-site/scripts/form-validation.min.c71b4f9b.js");
#
#
#
#
#
#
#
#
#
#     OAM.arriveOnceAndLoad('[data-datepicker]', "https://www.pigiame.co.ke/assets/pi-site/scripts/datepicker.min.42ef1544.js");
#
#
#
#
#
#     OAM.script("https://www.pigiame.co.ke/assets/pi-site/scripts/search-filter.min.b6312360.js");
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     OAM.arriveOnceAndLoad('[data-filter-select]', "https://www.pigiame.co.ke/assets/pi-site/scripts/select.min.3f04c8a8.js");
#
#     OAM.script("https://www.pigiame.co.ke/assets/pi-site/scripts/smartbanner.min.a4350a54.js");
#
#
#
#
#
#
#
#
#
#
#
#
#
#     OAM.arriveOnceAndLoad('[data-listing-card-show-email]', "https://www.pigiame.co.ke/assets/pi-site/scripts/contact-methods.min.c9cf9232.js");
#
#
#
#
#
#     OAM.script("https://www.pigiame.co.ke/assets/pi-site/scripts/recaptcha.min.3b3fb8be.js");
#
#     OAM.arriveOnceAndLoad('[data-user-notice]', "https://www.pigiame.co.ke/assets/pi-site/scripts/message.min.39dd848a.js");
#
#     OAM.arriveOnceAndLoad('[data-message-truncate]', "https://www.pigiame.co.ke/assets/pi-site/scripts/message-truncate.min.c45ca4a6.js");
#
#     OAM.arriveOnceAndLoad('[data-depends-on]', "https://www.pigiame.co.ke/assets/pi-site/scripts/data-depends.min.16315424.js");
#
#     OAM.script("https://www.pigiame.co.ke/assets/pi-site/scripts/alert-form.min.ca736722.js");
#
#
#
#
#
#     OAM.script("https://www.pigiame.co.ke/assets/pi-site/scripts/listing-form.min.a46fd90e.js");
#
#
#
#     OAM.arriveOnceAndLoad('[data-form-template]', "https://www.pigiame.co.ke/assets/pi-site/scripts/form-template.min.34328a55.js");
#
#
#
#
#
#
#
#
#
#
#
#
#
#             OAM.script("https://www.pigiame.co.ke/assets/pi-site/scripts/fonts.min.3f043630.js");
#
#             OAM.script("https://www.pigiame.co.ke/assets/pi-site/scripts/timezone.min.a2530f14.js");
#   </script>
#  </body>
# </html>

# %%
# Parsing our document: my_job_mag
# ---
#  
MJM = BeautifulSoup(MyJobMag.text, "html.parser")
print(MJM .prettify())
# Out:
# <!DOCTYPE doctype html>
# <html>
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="en" http-equiv="Content-Language"/>
#   <base href="https://www.myjobmag.co.ke/"/>
#   <title>
#    ICT / Computer Jobs in Kenya -  ICT / Computer Vacancies in Kenya February 2023 | MyJobMag
#   </title>
#   <meta content="See all latest ICT / Computer jobs in Kenya today. Check latest and verified vacancies in Kenya. Jobs for ICT / Computer professionals and jobseekers." name="description"/>
#   <link href="https://www.myjobmag.co.ke/jobs-by-field/information-technology" rel="canonical"/>
#   <link href="https://www.myjobmag.co.ke/jobs-by-field/information-technology/2" rel="next"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="1" name="revisit-after">
#    <meta content="1" name="refresh time"/>
#    <meta content="myjobmag.co.ke" name="copyright"/>
#    <meta content="Myjobmag" name="author"/>
#    <meta content="English" name="language"/>
#    <meta content="1" name="revisit-after"/>
#    <meta content="ICT / Computer Jobs in Kenya -  ICT / Computer Vacancies in Kenya February 2023 | MyJobMag" property="og:title"/>
#    <meta content="website" property="og:type"/>
#    <meta content="https://www.myjobmag.co.ke/jobs-by-field/information-technology" property="og:url"/>
#    <meta content="https://www.myjobmag.co.ke/images/myjobmag.png" property="og:image"/>
#    <meta content="My Job Mag" property="og:site_name"/>
#    <meta content="See all latest ICT / Computer jobs in Kenya today. Check latest and verified vacancies in Kenya. Jobs for ICT / Computer professionals and jobseekers." property="og:description"/>
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
#    <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#    <link href="/css/myjobmag.1673018618.css" rel="stylesheet" type="text/css"/>
#    <link href="/css/responsive.1675258654.css" rel="stylesheet" type="text/css"/>
#    <script async="" rel="preconnect" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#    </script>
#    <script>
#     (adsbygoogle = window.adsbygoogle || []).push({
#
#      google_ad_client: "ca-pub-0011597892009729",
#
#      enable_page_level_ads: true
#
#     });
#    </script>
#    <script async="" rel="preconnect" src="https://www.googletagmanager.com/gtag/js?id=UA-83297707-1">
#    </script>
#    <script>
#     window.dataLayer = window.dataLayer || [];
#
#
#   function gtag(){dataLayer.push(arguments);}
#
#
#
#   gtag('js', new Date());
#
#
#   gtag('config', 'UA-83297707-1');
#    </script>
#   </meta>
#  </head>
#  <body>
#   <div class="header" id="dheader">
#    <div class="content-wrap">
#     <a class="logo" href="/" id="d-site-logo">
#      <img alt="myjobmag logo" height="38px" src="/images/myjobmag-logo1.png?a" width="126px"/>
#     </a>
#     <nav>
#      <div id="menue-back-box" onclick="document.getElementById('check01').click()">
#      </div>
#      <input class="menu-check" id="check01" name="menu" onclick="checkMenueBox(this)" type="checkbox"/>
#      <label for="check01" id="menue-but-box">
#      </label>
#      <ul class="site-menu" id="nav-ul">
#       <li id="close-menue" onclick="closeMenueBox(this)">
#        X
#       </li>
#       <li class="nav-li" id="employer-postjob-nav">
#        <a class="nav-a" href="/employers/">
#         Employers, Post a Job
#        </a>
#       </li>
#       <li class="nav-li ">
#        <a class="nav-a" href="/" id="jobs-nav">
#         Jobs
#        </a>
#        <ul id="jobs-by-nav">
#         <li id="jobs-by-field-nav">
#          <a href="/jobs-by-field">
#           Jobs by Field
#          </a>
#         </li>
#         <li id="jobs-by-location-nav">
#          <a href="/jobs-location">
#           Jobs by Location
#          </a>
#         </li>
#         <li id="jobs-by-education-nav">
#          <a href="/jobs-by-education">
#           Jobs by Education
#          </a>
#         </li>
#         <li id="jobs-by-industry-nav">
#          <a href="/jobs-by-industry">
#           Jobs by Industry
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav-li ">
#        <a class="nav-a" href="/blog" id="get-advice-nav" target="_blank">
#         Get Advice
#        </a>
#        <ul id="jobs-by-nav">
#         <li id="career-advice-nav">
#          <a href="/blog" target="_blank">
#           Career Advice
#          </a>
#         </li>
#         <li id="hr-recruiter-advice-nav">
#          <a href="/blog/category/hr-advice" target="_blank">
#           HR/Recruiter Advice
#          </a>
#         </li>
#         <li id="job-trends-nav">
#          <a href="/job-trends">
#           Job Trends
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="nav-li ">
#        <a class="nav-a" href="/cv" id="cv-builder-nav">
#         CV Builder
#        </a>
#       </li>
#       <li class="nav-li ">
#        <a class="nav-a" href="https://www.mysalaryscale.com/ke" id="salaries-nav" target="_blank">
#         Salaries
#        </a>
#       </li>
#       <li class="nav-li ">
#        <a class="nav-a" href="/employers/" id="post-jobs-nav">
#         Post Jobs
#        </a>
#       </li>
#       <li class="nav-li" id="post-a-job-navx">
#        <a class="nav-a" href="/employers/">
#         Post A Job / Recruit
#        </a>
#       </li>
#       <li class="nav-li" id="login-nav">
#        <a class="nav-a" href="/login" id="nav-login-id" style=" border:none">
#         Login
#        </a>
#       </li>
#       <li class="nav-li" id="signup-nav">
#        <a class="nav-a" href="/signup" id="nav-signup-id" style=" border:none">
#         Signup
#        </a>
#       </li>
#      </ul>
#     </nav>
#     <ul class="nav-2" id="login-signup-ul" style="margin-right:0px">
#      <li>
#       <a href="/login" style=" border-color:#FFF">
#        Login
#       </a>
#      </li>
#      <li>
#       <a href="/signup" id="nav-2-signup">
#        Signup
#       </a>
#      </li>
#      <li id="ls-employers" style="padding-right:0px;">
#       <a href="/employers/" id="hd-emp-but" title="Post a Job">
#        Employers
#       </a>
#      </li>
#     </ul>
#     <div class="switch-country">
#      <input class="country-menu-check" id="check02" name="menu" type="checkbox"/>
#      <label class="switch-country-a" for="check02" style="background-image:url(/pictures/flag/435641681_kenya-flag.jpg), url(../images/icons.png)">
#       Kenya
#      </label>
#      <ul id="switch-country-ul">
#       <li>
#        <a href="https://www.myjobmagghana.com" style="background-image:url(/pictures/flag/491801725_gh.jpg)">
#         Ghana
#        </a>
#       </li>
#       <li>
#        <a href="https://www.myjobmag.co.ke" style="background-image:url(/pictures/flag/435641681_kenya-flag.jpg)">
#         Kenya
#        </a>
#       </li>
#       <li>
#        <a href="https://www.myjobmag.com" style="background-image:url(/pictures/flag/865758178_nigerian-flag.jpg)">
#         Nigeria
#        </a>
#       </li>
#       <li>
#        <a href="https://www.myjobmag.ph" style="background-image:url(/pictures/flag/)">
#         Philippines
#        </a>
#       </li>
#       <li>
#        <a href="https://www.myjobmag.co.za" style="background-image:url(/pictures/flag/419479899_south-africa-flag.jpg)">
#         South Africa
#        </a>
#       </li>
#      </ul>
#     </div>
#     <a class="mobile-search-icon" href="javascript:;" onclick="showSearchBox(1,this)">
#     </a>
#    </div>
#   </div>
#   <div class="mobile-nav">
#    <a href="/" id="mn-jobs">
#     Jobs
#    </a>
#    <a href="/blog" id="mn-advice">
#     Career Advice
#    </a>
#    <a href="/signup" id="mn-signup" style=" border-right:none">
#     Signup
#    </a>
#   </div>
#   <div id="search-box-wrap2">
#    <div class="dsearch-class1" id="search">
#     <div class="content-wrap">
#      <form action="/search/jobs" class="search-form" method="get">
#       <label id="search-title">
#        Search for Jobs
#       </label>
#       <div class="search-input-wrap">
#        <div class="search-input-box">
#         <input autocomplete="off" class="search-input" id="search-key" name="q" placeholder="Company Name or Job Title" type="text"/>
#        </div>
#        <div class="search-input-box">
#         <input class="search-input" id="search-location" onclick="dropMultiSelect(this,this.nextSibling);" readonly="readonly" style="color:#CCC" title="Location" type="text" value="Location"/>
#         <div class="select-option-house">
#          <div id="select-option-box">
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Nairobi"/>
#            Nairobi
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Mombasa"/>
#            Mombasa
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Baringo"/>
#            Baringo
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Bomet"/>
#            Bomet
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Bungoma"/>
#            Bungoma
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Busia"/>
#            Busia
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Chuka"/>
#            Chuka
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Eldoret"/>
#            Eldoret
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Elgeyo Marakwet"/>
#            Elgeyo Marakwet
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Embu"/>
#            Embu
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Garissa"/>
#            Garissa
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Homa Bay"/>
#            Homa Bay
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Isiolo"/>
#            Isiolo
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kajiado"/>
#            Kajiado
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kakamega"/>
#            Kakamega
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Karatina"/>
#            Karatina
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kericho"/>
#            Kericho
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kerugoya"/>
#            Kerugoya
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kiambu"/>
#            Kiambu
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kilifi"/>
#            Kilifi
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kirinyaga"/>
#            Kirinyaga
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kisii"/>
#            Kisii
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kisumu"/>
#            Kisumu
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kitale"/>
#            Kitale
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kitengela"/>
#            Kitengela
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kitui"/>
#            Kitui
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Kwale"/>
#            Kwale
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Laikipia"/>
#            Laikipia
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Lamu"/>
#            Lamu
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Machakos"/>
#            Machakos
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Makueni"/>
#            Makueni
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Mandera"/>
#            Mandera
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Marsabit"/>
#            Marsabit
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Meru"/>
#            Meru
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Migori"/>
#            Migori
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Muranga"/>
#            Muranga
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Nakuru"/>
#            Nakuru
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Nandi"/>
#            Nandi
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Nanyuki"/>
#            Nanyuki
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Narok"/>
#            Narok
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Nyamira"/>
#            Nyamira
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Nyandarua"/>
#            Nyandarua
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Nyeri"/>
#            Nyeri
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Samburu"/>
#            Samburu
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Siaya"/>
#            Siaya
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Taita Taveta"/>
#            Taita Taveta
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Tana River"/>
#            Tana River
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Tharaka Nithi"/>
#            Tharaka Nithi
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Thika"/>
#            Thika
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Trans Nzoia"/>
#            Trans Nzoia
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Turkana"/>
#            Turkana
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Uasin Gishu"/>
#            Uasin Gishu
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Vihiga"/>
#            Vihiga
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="Wajir"/>
#            Wajir
#           </label>
#           <label class="mag-b bp-bt-5" id="input-rap">
#            <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'location')" type="checkbox" value="West Pokot"/>
#            West Pokot
#           </label>
#          </div>
#         </div>
#        </div>
#        <div id="advance-fields">
#         <div class="search-input-box">
#          <input class="search-input" id="search-field" onclick="dropMultiSelect(this,this.nextSibling);" readonly="readonly" style="color:#CCC" title="Field" type="text" value="Field"/>
#          <div class="select-option-house">
#           <div id="select-option-box">
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Administration / Secretarial"/>
#             Administration / Secretarial
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Agriculture / Agro-Allied"/>
#             Agriculture / Agro-Allied
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Art / Crafts / Languages"/>
#             Art / Crafts / Languages
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Aviation / Airline"/>
#             Aviation / Airline
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Banking"/>
#             Banking
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Building and Construction"/>
#             Building and Construction
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Catering / Confectionery"/>
#             Catering / Confectionery
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Consultancy"/>
#             Consultancy
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Customer Care"/>
#             Customer Care
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Data Science / Research"/>
#             Data Science / Research
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Driving"/>
#             Driving
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Education / Teaching"/>
#             Education / Teaching
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Engineering / Technical"/>
#             Engineering / Technical
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Expatriate"/>
#             Expatriate
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Finance / Accounting / Audit"/>
#             Finance / Accounting / Audit
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="General"/>
#             General
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Graduate Jobs"/>
#             Graduate Jobs
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Hospitality / Hotel / Restaurant"/>
#             Hospitality / Hotel / Restaurant
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Human Resources / HR"/>
#             Human Resources / HR
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="ICT / Computer"/>
#             ICT / Computer
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Insurance"/>
#             Insurance
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Internships / Volunteering"/>
#             Internships / Volunteering
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Janitorial Services"/>
#             Janitorial Services
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Law / Legal"/>
#             Law / Legal
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Logistics"/>
#             Logistics
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Manufacturing"/>
#             Manufacturing
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Media / Advertising / Branding"/>
#             Media / Advertising / Branding
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Medical / Healthcare"/>
#             Medical / Healthcare
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="MyJobMag"/>
#             MyJobMag
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="NGO/Non-Profit"/>
#             NGO/Non-Profit
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Oil and Gas / Energy"/>
#             Oil and Gas / Energy
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Pharmaceutical"/>
#             Pharmaceutical
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Procurement / Store-keeping / Supply Chain"/>
#             Procurement / Store-keeping / Supply Chain
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Product Management"/>
#             Product Management
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Project Management"/>
#             Project Management
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Real Estate"/>
#             Real Estate
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Safety and Environment / HSE"/>
#             Safety and Environment / HSE
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Sales / Marketing / Retail / Business Development"/>
#             Sales / Marketing / Retail / Business Development
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Science"/>
#             Science
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Security / Intelligence"/>
#             Security / Intelligence
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'field')" type="checkbox" value="Travels &amp; Tours"/>
#             Travels &amp; Tours
#            </label>
#           </div>
#          </div>
#         </div>
#         <div class="search-input-box">
#          <input class="search-input" id="search-industry" onclick="dropMultiSelect(this,this.nextSibling);" readonly="readonly" style="color:#CCC" title="Industry" type="text" value="Industry"/>
#          <div class="select-option-house">
#           <div id="select-option-box">
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Engineering / Technical"/>
#             Engineering / Technical
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Healthcare / Medical"/>
#             Healthcare / Medical
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Creative / Arts"/>
#             Creative / Arts
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Education / Teaching"/>
#             Education / Teaching
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Oil and Gas / Marine"/>
#             Oil and Gas / Marine
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Manufacturing / Production / FMCG"/>
#             Manufacturing / Production / FMCG
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Media / Radio / TV"/>
#             Media / Radio / TV
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Agriculture / Agro-Allied"/>
#             Agriculture / Agro-Allied
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="NGO / Non-Profit Associations"/>
#             NGO / Non-Profit Associations
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Government"/>
#             Government
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Building / Construction"/>
#             Building / Construction
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Hospitality"/>
#             Hospitality
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Insurance"/>
#             Insurance
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Law / Legal"/>
#             Law / Legal
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Consulting"/>
#             Consulting
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Banking / Financial Services"/>
#             Banking / Financial Services
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Food Services"/>
#             Food Services
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="ICT / Telecommunication"/>
#             ICT / Telecommunication
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Travel and Tours"/>
#             Travel and Tours
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Logistics and Transportation"/>
#             Logistics and Transportation
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Sales / Retail"/>
#             Sales / Retail
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="General"/>
#             General
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Real Estate"/>
#             Real Estate
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Security"/>
#             Security
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Aviation / Airline"/>
#             Aviation / Airline
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Pharmaceuticals"/>
#             Pharmaceuticals
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Religious"/>
#             Religious
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Advertising / Branding / PR"/>
#             Advertising / Branding / PR
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Online Sales / Marketing"/>
#             Online Sales / Marketing
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Professional / Social Associations"/>
#             Professional / Social Associations
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Janitorial Services / Environment"/>
#             Janitorial Services / Environment
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Power / Energy"/>
#             Power / Energy
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Research"/>
#             Research
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Science"/>
#             Science
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Internet / E-commerce"/>
#             Internet / E-commerce
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Raffle"/>
#             Raffle
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'industry')" type="checkbox" value="Blockchain"/>
#             Blockchain
#            </label>
#           </div>
#          </div>
#         </div>
#         <div class="search-input-box">
#          <input class="search-input" id="search-education" onclick="dropMultiSelect(this,this.nextSibling);" readonly="readonly" style="color:#CCC" title="Education" type="text" value="Education"/>
#          <div class="select-option-house">
#           <div id="select-option-box">
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="BA/BSc/HND"/>
#             BA/BSc/HND
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="Diploma"/>
#             Diploma
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="First School Leaving Certificate"/>
#             First School Leaving Certificate
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="KCSE"/>
#             KCSE
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="MBA/MSc/MA"/>
#             MBA/MSc/MA
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="NCE"/>
#             NCE
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="Others"/>
#             Others
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="PhD/Fellowship"/>
#             PhD/Fellowship
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'education')" type="checkbox" value="Vocational"/>
#             Vocational
#            </label>
#           </div>
#          </div>
#         </div>
#         <div class="search-input-box">
#          <input class="search-input" id="search-experience" onclick="dropMultiSelect(this,this.nextSibling);" readonly="readonly" style="color:#CCC" title="Experience" type="text" value="Experience"/>
#          <div class="select-option-house">
#           <div id="select-option-box">
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'experience')" type="checkbox" value="None"/>
#             None
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'experience')" type="checkbox" value="1 - 4"/>
#             1 - 4 years
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'experience')" type="checkbox" value="5 - 10"/>
#             5 - 10 years
#            </label>
#            <label class="mag-b bp-bt-5" id="input-rap">
#             <input autocomplete="off" onchange="selectOption(this,this.parentNode.parentNode,'experience')" type="checkbox" value="11 - 35"/>
#             11 - 35 years
#            </label>
#           </div>
#          </div>
#         </div>
#         <div id="close-advance" onclick="closeAdvanceSearch(this)">
#          Close
#         </div>
#        </div>
#       </div>
#       <input class="search-but" id="search-but" type="submit" value="Search Job"/>
#       <div class="advance-search-but" id="advance-search-but" onclick="showAdvanceSearch(this)">
#        Advance Search
#       </div>
#      </form>
#     </div>
#    </div>
#   </div>
#   <section id="jobs-cat-sec">
#    <div class="content-wrap2">
#     <div class="left-section" id="cat-left-sec">
#      <div class="mag-b" id="cat-search-hold-box" style="">
#       <form action="/search/jobs" class="smart-search bm-t-40" id="job-search-form-2" method="get" onsubmit="">
#        <div class="smart-search-input">
#         <div id="selected-keyz">
#         </div>
#         <label class="fl-l bw-auto">
#          <input class="sm-s-input" id="s-keyword-input" placeholder="Type a keyword" value=""/>
#         </label>
#        </div>
#        <ul class="smart-search-fields">
#         <li id="ss-f-field" tabindex="0">
#          <div class="ss-f-but">
#           Field
#          </div>
#          <ul>
#           <li onclick="selectSearchField(this,'field','Administration / Secretarial')">
#            Administration / Secretarial
#           </li>
#           <li onclick="selectSearchField(this,'field','Agriculture / Agro-Allied')">
#            Agriculture / Agro-Allied
#           </li>
#           <li onclick="selectSearchField(this,'field','Art / Crafts / Languages')">
#            Art / Crafts / Languages
#           </li>
#           <li onclick="selectSearchField(this,'field','Aviation / Airline')">
#            Aviation / Airline
#           </li>
#           <li onclick="selectSearchField(this,'field','Banking')">
#            Banking
#           </li>
#           <li onclick="selectSearchField(this,'field','Building and Construction')">
#            Building and Construction
#           </li>
#           <li onclick="selectSearchField(this,'field','Catering / Confectionery')">
#            Catering / Confectionery
#           </li>
#           <li onclick="selectSearchField(this,'field','Consultancy')">
#            Consultancy
#           </li>
#           <li onclick="selectSearchField(this,'field','Customer Care')">
#            Customer Care
#           </li>
# ...
#          Jobs in Nyanza
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-region/nairobi" title="Jobs in Nairobi">
#          Jobs in Nairobi
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-region/central" title="Jobs in Central">
#          Jobs in Central
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-region/coast" title="Jobs in Coast">
#          Jobs in Coast
#         </a>
#        </li>
#       </ul>
#       <ul class="category-box" style="border-bottom:none;">
#        <li id="job-cat-head">
#         Job By Industry
#        </li>
#        <li style="width:100%">
#         <div class="h3-line bm-b-20">
#         </div>
#        </li>
#        <li>
#         <a href="/jobs-by-industry/engineering" title="Engineering / Technical Jobs">
#          Engineering / Technical Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-industry/medical" title="Healthcare / Medical Jobs">
#          Healthcare / Medical Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-industry/creative" title="Creative / Arts Jobs">
#          Creative / Arts Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-industry/education" title="Education / Teaching Jobs">
#          Education / Teaching Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-industry/oil-and-gas" title="Oil and Gas / Marine Jobs">
#          Oil and Gas / Marine Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-industry/agriculture" title="Agriculture / Agro-Allied Jobs">
#          Agriculture / Agro-Allied Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-industry/manufacturing" title="Manufacturing / Production / FMCG Jobs">
#          Manufacturing / Production / FMCG Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-industry/broadcasting" title="Media / Radio / TV Jobs">
#          Media / Radio / TV Jobs
#         </a>
#        </li>
#        <li style="width:100%">
#         <a href="/jobs-by-industry" id="view-all">
#          Search jobs by industry
#         </a>
#        </li>
#       </ul>
#       <ul class="category-box" style="border-bottom:none;">
#        <li id="job-cat-head">
#         Job By Title
#        </li>
#        <li style="width:100%">
#         <div class="h3-line bm-b-20">
#         </div>
#        </li>
#        <li>
#         <a href="/jobs-by-title/accountant" title="Accountant Jobs">
#          Accountant Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-title/sales-executive" title="Sales Executive Jobs">
#          Sales Executive Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-title/business-development-manager" title="Business Development Manager Jobs">
#          Business Development Manager Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-title/driver" title="Driver Jobs">
#          Driver Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-title/finance-manager" title="Finance Manager Jobs">
#          Finance Manager Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-title/project-manager" title=" Project Manager Jobs">
#          Project Manager Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-title/internal-auditor" title="Internal Auditor Jobs">
#          Internal Auditor Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-title/sales-manager" title="Sales Manager Jobs">
#          Sales Manager Jobs
#         </a>
#        </li>
#        <li style="width:100%">
#         <a href="/job-titles" id="view-all" title="Search jobs by title">
#          Search jobs by title
#         </a>
#        </li>
#       </ul>
#       <ul class="category-box" style="border-bottom:none;">
#        <li id="job-cat-head">
#         Job By Type
#        </li>
#        <li style="width:100%">
#         <div class="h3-line bm-b-20">
#         </div>
#        </li>
#        <li>
#         <a href="/jobs-by-type/contract" title="Contract Jobs">
#          Contract Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-type/full-time" title="Full Time Jobs">
#          Full Time Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-type/part-time" title="Part Time Jobs">
#          Part Time Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-type/expatriate" title="Expatriate Jobs">
#          Expatriate Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-type/remote" title="Remote Jobs">
#          Remote Jobs
#         </a>
#        </li>
#       </ul>
#       <ul class="category-box">
#        <li id="job-cat-head">
#         Job By Date
#        </li>
#        <li style="width:100%">
#         <div class="h3-line bm-b-20">
#         </div>
#        </li>
#        <li>
#         <a href="/jobs-by-date/today" title="Today Jobs">
#          Today Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-date/yesterday" title="Yesterday Jobs">
#          Yesterday Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-date/this-week" title="This Week Jobs">
#          This Week Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-date/last-week" title="Last Week Jobs">
#          Last Week Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-date/this-month" title="This Month Jobs">
#          This Month Jobs
#         </a>
#        </li>
#        <li>
#         <a href="/jobs-by-date/last-month" title="Last Month Jobs">
#          Last Month Jobs
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="mag-b bm-b-30">
#       <div id="adbox">
#        <ins class="adsbygoogle" data-ad-client="ca-pub-4056521106463804" data-ad-format="auto" data-ad-slot="7359083834" data-full-width-responsive="true" style="display:block">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </div>
#      </div>
#      <div class="mag-b">
#       <div id="subscription" style="width: 90%; padding-left: 5%; padding-right: 5%; padding-top: 30px; padding-bottom: 30px; margin-top: 0px; margin-bottom: 20px">
#        <div class="mag-b">
#         <h2 class="main-h2">
#          Subscribe to Job Alert
#         </h2>
#         <div class="h2-line bm-b-10" id="subscr-h2-line">
#         </div>
#         <p class="center ts-14 tc-b66">
#          Join our happy subscribers
#         </p>
#        </div>
#        <form action="/subscribe" class="subscribe-form" method="post" name="subscribe-form">
#         <input autocomplete="off" class="subscribe-input" id="subscribe-user-email2" name="subscribe_email_input" onclick="activeSubscribe(this)" onkeyup="showEmailHost(this)" placeholder="Enter your email here!" style="" type="email" value=""/>
#         <input autocomplete="off" id="subscribe-user-name" name="first_name" type="text"/>
#         <input autocomplete="off" id="subscribe-user-mail" name="mail" type="checkbox" value="yes"/>
#         <input id="subscribe-but2" type="submit" value="Subscribe"/>
#         <input name="subscribe_token" type="hidden" value="791e1dd8af6092a47cd3f0ee38fb4d95"/>
#         <div id="mail-host-house" style="margin-top: 0px">
#          <ul class="mail-hosts">
#           <li onclick="choseEmailHost(this)">
#            @gmail.com
#           </li>
#           <li onclick="choseEmailHost(this)">
#            @yahoo.com
#           </li>
#           <li onclick="choseEmailHost(this)">
#            @outlook.com
#           </li>
#          </ul>
#         </div>
#        </form>
#       </div>
#      </div>
#      <div class="mag-b bm-b-50">
#       <div class="box-title">
#        <h2>
#         Career Advice
#        </h2>
#       </div>
#       <ul class="job-tips">
#        <li class="" style="border-bottom:none">
#         <h3>
#          <a href="/blog/windle-trust-international-postgraduate-scholarship-application">
#           Windle Trust International Postgraduate Scholarship Application
#          </a>
#         </h3>
#        </li>
#        <li class="bg-a4" style="border-bottom:none">
#         <h3>
#          <a href="/blog/usiu-africa-2023-mastercard-foundation-scholars-program-for-undergraduate-students">
#           USIU-Africa 2023 Mastercard Foundation Scholars Program for Undergraduate Students
#          </a>
#         </h3>
#        </li>
#        <li class="" style="border-bottom:none">
#         <h3>
#          <a href="/blog/microsoft-2022-software-engineers-from-african-universities-to-join-team-in-the-us-and-canada">
#           Microsoft 2022 Software Engineers from African Universities to Join Team in the US and Canada
#          </a>
#         </h3>
#        </li>
#        <li class="bg-a4" style="border-bottom:none">
#         <h3>
#          <a href="/blog/how-to-write-job-application-letter-sample-for-any-position">
#           How To Write Job Application Letter Sample For Any Position
#          </a>
#         </h3>
#        </li>
#       </ul>
#       <a class="view-all-post" href="/blog">
#        View All Career Advice
#       </a>
#      </div>
#      <div class="mag-b" id="br-all-str-rt">
#      </div>
#      <div class="mag-b bm-b-50" id="right-main-ad3">
#       <div id="adbox">
#        <ins class="adsbygoogle" data-ad-client="ca-pub-4056521106463804" data-ad-format="auto" data-ad-slot="7359083834" data-full-width-responsive="true" style="display:block">
#        </ins>
#        <script>
#         (adsbygoogle = window.adsbygoogle || []).push({});
#        </script>
#       </div>
#      </div>
#     </div>
#    </div>
#   </section>
#   <div class="mag-b" id="main-subscribe-box">
#    <div id="subscription">
#     <div class="content-wrap">
#      <div class="mag-b">
#       <h2 class="main-h2">
#        Subscribe to Job Alert
#       </h2>
#       <div class="h2-line bm-b-10" id="subscr-h2-line">
#       </div>
#       <p class="center ts-14 tc-b66">
#        Join our happy subscribers
#       </p>
#      </div>
#      <form action="/subscribe" class="subscribe-form" method="post" name="subscribe-form">
#       <input autocomplete="off" class="subscribe-input" id="subscribe-user-email" name="subscribe_email_input" onclick="activeSubscribe(this)" onkeyup="showEmailHost(this)" placeholder="Enter your email here!" type="email" value=""/>
#       <input autocomplete="off" id="subscribe-user-name" name="first_name" type="text"/>
#       <input autocomplete="off" id="subscribe-user-mail" name="mail" type="checkbox" value="yes"/>
#       <input id="subscribe-but" type="submit" value="Subscribe"/>
#       <input name="subscribe_token" type="hidden" value="791e1dd8af6092a47cd3f0ee38fb4d95"/>
#       <div id="mail-host-house">
#        <ul class="mail-hosts">
#         <li onclick="choseEmailHost(this)">
#          @gmail.com
#         </li>
#         <li onclick="choseEmailHost(this)">
#          @yahoo.com
#         </li>
#         <li onclick="choseEmailHost(this)">
#          @outlook.com
#         </li>
#        </ul>
#       </div>
#      </form>
#     </div>
#    </div>
#   </div>
#   <div class="cat-desc-box">
#    <h2 class="ts-20">
#     Job Vacancies in ICT / Computer
#    </h2>
#    The IT industry is popular for its diverse and wide range of job titles and great scope of roles, which can get some people confused about which area to take a dive in. If you have carefully considered a niche of job in the IT sector you'd feel more comfortable to explore, be certain that there are limitless jobs for you in IT. Some roles include: software engineer, system analyst, business analyst, technical support, network engineer, technical sales person, web developer, software tester etc. Consider it carefully.
# Ict jobs are usually advertised by myjobmag.com. Check our job publications in fields like it, ict etc. plus their online equivalents.
#   </div>
#   <footer id="main-footer">
#    <div class="content-wrap">
#     <ul class="footer-ul">
#      <li class="mjm-desc">
#      </li>
#      <li class="footer-list">
#       <ul>
#        <li id="footer-title">
#         Candidates
#        </li>
#        <li id="footer-head-line">
#        </li>
#        <li>
#         <a href="/" target="_blank">
#          Job Listing
#         </a>
#        </li>
#        <li>
#         <a href="/cv" target="_blank">
#          CV Builder
#         </a>
#        </li>
#        <li>
#         <a href="https://www.mysalaryscale.com/ke" target="_blank">
#          Salaries &amp; Reviews
#         </a>
#        </li>
#        <li>
#         <a href="/internship/" target="_blank">
#          Internship
#         </a>
#        </li>
#        <li>
#         <a href="/blog" target="_blank">
#          Career Tips &amp; Info
#         </a>
#        </li>
#        <li>
#         <a href="/course" target="_blank">
#          Training
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="footer-list">
#       <ul>
#        <li id="footer-title">
#         Companies
#        </li>
#        <li id="footer-head-line">
#        </li>
#        <li>
#         <a href="/employers/" target="_blank">
#          Post a Job
#         </a>
#        </li>
#        <li>
#         <a href="/shortlist" target="_blank">
#          Shortlisting Service
#         </a>
#        </li>
#        <li>
#         <a href="/recruitment" target="_blank">
#          Recruitment Service
#         </a>
#        </li>
#        <li>
#         <a href="/employers/find-candidates" target="_blank">
#          Candidate Search
#         </a>
#        </li>
#        <li>
#         <a href="/advertise" target="_blank">
#          Advertise
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="footer-list">
#       <ul>
#        <li id="footer-title">
#         Sharing
#        </li>
#        <li id="footer-head-line">
#        </li>
#        <li>
#         <a href="/widget/feed-widget">
#          Job Widget
#         </a>
#        </li>
#        <li>
#         <a href="/feeds/">
#          XML Feed
#         </a>
#        </li>
#        <li>
#         <a href="/sitemap">
#          Sitemap (HTML)
#         </a>
#        </li>
#        <li>
#         <a href="/testimonies">
#          Testimonials
#         </a>
#        </li>
#        <li>
#         <a href="/faq">
#          Help - FAQs
#         </a>
#        </li>
#        <li>
#         <ul class="social-box">
#          <li>
#           <a class="" href="https://www.facebook.com/myjobmag.co.ke" id="social-facebook" rel="nofollow" target="_blank">
#           </a>
#          </li>
#          <li>
#           <a class="" href="https://twitter.com/MyjobmagKenya" id="social-twitter" rel="nofollow" target="_blank">
#           </a>
#          </li>
#          <li>
#           <a class="" href="https://www.linkedin.com/company/11093105/" id="social-linkedin" rel="nofollow" target="_blank">
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#      </li>
#      <li class="footer-list">
#       <ul>
#        <li id="footer-title">
#         Myjobmag Africa
#        </li>
#        <li id="footer-head-line">
#        </li>
#        <li>
#         <a href="https://www.myjobmagghana.com">
#          Jobs in Ghana
#         </a>
#        </li>
#        <li>
#         <a href="https://www.myjobmag.co.ke">
#          Jobs in Kenya
#         </a>
#        </li>
#        <li>
#         <a href="https://www.myjobmag.com">
#          Jobs in Nigeria
#         </a>
#        </li>
#        <li>
#         <a href="https://www.myjobmag.ph">
#          Jobs in Philippines
#         </a>
#        </li>
#        <li>
#         <a href="https://www.myjobmag.co.za">
#          Jobs in South Africa
#         </a>
#        </li>
#        <li>
#        </li>
#       </ul>
#      </li>
#     </ul>
#     <div class="footer-butom">
#      <a href="/about" target="_blank">
#       About
#      </a>
#      <a href="/contact" target="_blank">
#       Contact
#      </a>
#      <a href="/privacy" target="_blank">
#       Privacy Policy
#      </a>
#      <a href="/terms" target="_blank">
#       Terms
#      </a>
#      <a href="mailto:services@myjobmag.co.ke" id="footer-email">
#       <b>
#        services@myjobmag.co.ke
#       </b>
#      </a>
#      <span class="copy-rit">
#       Copyright © 2023
#       <a href="/" style="border-right-style:none">
#        MyJobMagKenya
#       </a>
#      </span>
#     </div>
#    </div>
#   </footer>
#   <a class="js-cd-top" href="#0" id="scroll-to-top">
#   </a>
#   <script language="javascript" src="/js/scroll-page.1675249800.js" type="text/javascript">
#   </script>
#   <script>
#    //setTimeout('abcdload()',2000);
#   </script>
#  </body>
# </html>

# %%
# Parsing our document: kenyan_job
# ---
# 
kenyan_job = BeautifulSoup(KenyanJob.text, "html.parser")
print(kenyan_job .prettify())
# Out:
# <!DOCTYPE html>
# <!-- paulirish.com/2008/conditional-stylesheets-vs-css-hacks-answer-neither/ -->
# <!--[if lt IE 7]> <html class="no-js ie6 ie" xmlns="http://www.w3.org/1999/xhtml" lang="en-GB" dir="ltr"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 ie" xmlns="http://www.w3.org/1999/xhtml" lang="en-GB" dir="ltr"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 ie" xmlns="http://www.w3.org/1999/xhtml" lang="en-GB" dir="ltr"> <![endif]-->
# <!--[if IE 9]>    <html class="no-js ie9 ie" xmlns="http://www.w3.org/1999/xhtml" lang="en-GB" dir="ltr"> <![endif]-->
# <!--[if gt IE 9]><!-->
# <html class="no-js" dir="ltr" lang="en-GB" prefix="content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ og: http://ogp.me/ns# rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#" xmlns="http://www.w3.org/1999/xhtml">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
#   <link href="https://www.kenyajob.com/sites/all/themes/africawork2/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
#   <meta content="
#   Enter your keywords
#
#
#
#
#    Retain current filters
#
#
#
#
# Filter54 éléments trouvé.IT, software engineering, Internet Apply IT, software engineering, Internet filter
# " name="description"/>
#   <link href="https://www.kenyajob.com/job-vacancies-search-kenya" rel="canonical"/>
#   <link href="https://www.kenyajob.com/job-vacancies-search-kenya" rel="shortlink"/>
#   <title>
#    IT, software engineering, Internet Jobs Kenya | Kenyajob.com
#   </title>
#   <link href="https://www.kenyajob.com/sites/kenyajob.com/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.kenyajob.com/sites/kenyajob.com/files/css/css_RrIaXHIDgOsC727EgAbl6WymmGuUu2LFXADcokToV8c.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.kenyajob.com/sites/kenyajob.com/files/css/css_Ls3uBHalfLpixuZq_CjWcy6ZvefdEyCDN_e8EZsl8YM.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.kenyajob.com/sites/kenyajob.com/files/css/css_f1N185LOoXhTCZLHoT8dr4SugEppkKbmZUHgL3oV7E8.css" media="all" rel="stylesheet" type="text/css"/>
#   <link href="https://www.kenyajob.com/sites/kenyajob.com/files/css/css_A-XTpg_a36zgn9tKfRsqGvRTLRp1QDOuSQfBoQxEg_Q.css" media="all" rel="stylesheet" type="text/css"/>
#   <script src="https://www.kenyajob.com/sites/kenyajob.com/files/js/js_s5koNMBdK4BqfHyHNPWCXIL2zD0jFcPyejDZsryApj0.js" type="text/javascript">
#   </script>
#   <script src="https://www.kenyajob.com/sites/kenyajob.com/files/js/js_H7q2xORKmR9AN8Qx5spKEIBp7R_wG2apAswJoCUZY7I.js" type="text/javascript">
#   </script>
#   <script src="https://www.kenyajob.com/sites/kenyajob.com/files/js/js__3DdA3VAhtOe-ie8W49ohxs1svU9vw2GvGq9sjtxSKw.js" type="text/javascript">
#   </script>
#   <script src="https://www.kenyajob.com/sites/kenyajob.com/files/js/js_bDWwFRTcuHWVHRLXJsIABTyg07zOMuEjGpCzV0p5XXY.js" type="text/javascript">
#   </script>
#   <script src="https://www.kenyajob.com/sites/kenyajob.com/files/js/js_vgc3z8D8E5d3Ie1e9CJuH2p2EMYPZ4fUDlMOhUaLm-U.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    <!--//--><![CDATA[//><!--
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","setHasJsCookie":0,"ajaxPageState":{"theme":"africawork2","theme_token":"x1b6yc7N3XHAiBIOEPB6ia5XS58BDAtM8hRTFVjPxnE","js":{"sites\/all\/modules\/contrib\/jquery_update\/replace\/jquery\/1.10\/jquery.min.js":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery-html-prefilter-3.5.0-backport.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/modules\/contrib\/jquery_update\/replace\/ui\/external\/jquery.cookie.js":1,"sites\/all\/modules\/contrib\/admin_menu\/admin_devel\/admin_devel.js":1,"sites\/all\/modules\/contrib\/collapsiblock\/collapsiblock.js":1,"sites\/all\/modules\/custom\/emacustomizations\/js\/pushup.js":1,"public:\/\/languages\/en-GB_4fkVwagiAQdumRc157XRJSjjiRboJX9Pqcfk5D9yf98.js":1,"sites\/all\/modules\/contrib\/facetapi\/facetapi.js":1,"sites\/all\/modules\/custom\/ematching\/js\/ematching.js":1,"sites\/all\/themes\/africawork2\/js\/script.js":1,"sites\/all\/themes\/fusion\/fusion_core\/skins\/core\/js\/script.js":1,"sites\/all\/themes\/africawork2\/js\/jquery_example.js":1,"sites\/all\/themes\/africawork2\/js\/bootstrap.min.js":1,"sites\/all\/themes\/africawork2\/js\/bootstrap.js":1,"sites\/all\/themes\/africawork2\/js\/respond.min.js":1,"sites\/all\/themes\/africawork2\/js\/scrollReveal.min.js":1,"sites\/all\/themes\/africawork2\/js\/jquery.flexmenu.js":1,"sites\/all\/themes\/africawork2\/js\/jquery.ba-cond.min.js":1,"sites\/all\/themes\/africawork2\/js\/jquery.slitslider.js":1,"sites\/all\/themes\/africawork2\/js\/parallax.js":1,"sites\/all\/themes\/africawork2\/js\/jquery.counterup.min.js":1,"sites\/all\/themes\/africawork2\/js\/waypoints.min.js":1,"sites\/all\/themes\/africawork2\/js\/jquery.nouislider.all.min.js":1,"sites\/all\/themes\/africawork2\/js\/bootstrap3-wysihtml5.all.min.js":1,"sites\/all\/themes\/africawork2\/js\/jflickrfeed.min.js":1,"sites\/all\/themes\/africawork2\/js\/fancybox.pack.js":1,"sites\/all\/themes\/africawork2\/js\/settings.js":1,"sites\/all\/themes\/africawork2\/js\/intlTelInput.js":1,"sites\/all\/themes\/africawork2\/js\/script_2.js":1,"sites\/all\/themes\/africawork2\/js\/jquery.mCustomScrollbar.concat.min.js":1}},"collapsiblock":{"blocks":{"block-views-employers-directory-block":"1","block-views--exp-employers-directory-page":"2","block-emawebform-emawebform-contact-recruitment":"1","block-apachesolr-search-mlt-002":"1","block-apachesolr-search-mlt-001":"1","block-facetapi-7gsu08olrsut1fegnb5orbokh25juhoc":"3","block-facetapi-uxwf8wadg08f9ddiejao0ealo4dgqjmq":"3","block-facetapi-ilinwzm0o1fnlwpfmkt7gzsyh6turw5d":"2","block-facetapi-ucr3qmd6z52772lmqvl1w1pzfvwzo7h9":"3","block-facetapi-yqbrpkd6hrrqrh1jp9v090omp7bt2a4x":"3","block-facetapi-rwehvj3dz9rp1fog6lu1sh42smzztecu":"3","block-facetapi-eghgbid2cb0w0gmcfvrw8dfyepbgm25e":"3","block-views--exp-gestion-candidatures-page":"2","block-emasearch-emasearch-homepage-jobsearch-box":"1","block-current-search-standard":"1","block-current-search-jobsearch":"1","block-emacustomizations-footer-candidate":"1","block-facetapi-dawnucadngmsnfkdg2jkf8eqx3zg5hgz":"3","block-facetapi-vmglnefysjcl0qbebzgogkeyyag2fvey":"3","block-facetapi-nskor1kswgvbowzszx9va0wwqfhdtpge":"3","block-facetapi-ax1fjqgbrrmuaedewmkzq0ghlinpwzxo":"3","block-facetapi-qayivrvmh7a0ox96lnt0vnta2fc2jqnv":"2","block-facetapi-0m0fe0tq0rdj0zgvfl6a7penkqkb7idg":"3","block-facetapi-oxobk0e1ydp2i4yufnkbnnbxkjgwy8vt":"3","block-emawebform-emawebform-contact-info":"1","block-emacustomizations-footer-recruiter":"1","block-facetapi-2yzdoru0yf7thj8slwog5t1rvsieot8c":"3","block-facetapi-uan7m4lsysg7pz7qinsvapoj9ig3fohc":"3","block-facetapi-jdyewuclasrtl93trcxng0vfdq4gunc8":"3"},"default_state":"1","slide_type":"2","slide_speed":"400","block_title":":header:first","block":"div.block","block_content":"div.content"},"urlIsAjaxTrusted":{"\/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133":true},"facetapi":{"facets":[{"limit":"20","id":"facetapi-facet-apachesolrsolr-block-im-field-offre-metiers","searcher ...
# //--><!]]>
#   </script>
#   <script type="text/javascript">
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-23386561-12', 'auto');
#    ga('send', 'pageview');
#   </script>
#   <script type="text/javascript">
#    var trackOutboundLink = function(url, category, action) {
#      ga('send', 'event', category, action, url);
#     }
#   </script>
#  </head>
#  <body class="html not-front not-logged-in one-sidebar sidebar-second page-job-vacancies-search-kenya candidate-context i18n-en-GB font-size-13 grid-type-960 grid-width-16 sidebars-split role-other" id="pid-recherche-jobs-kenya">
#   <div id="skip-link">
#    <a href="#main-content-area">
#     Skip to main content area
#    </a>
#   </div>
#   <!-- HTML5 shiv and Respond.js IE8 support of HTML5 elements and media queres -->
#   <!--[if lt IE 9]>
#         <script src="js/html5shiv.js"></script>
#         <script src="js/respond.min.js"></script>
# <![endif]-->
#   <div id="loader">
#    <i class="fa fa-cog fa-4x fa-spin">
#    </i>
#   </div>
#   <!-- Menu -->
#   <div class="fm-container">
#    <!-- Menu -->
#    <div class="menu-left">
#     <div class="button-close text-right">
#      <a class="fm-button" id="button-close">
#       <i class="fa fa-close fa-2x">
#       </i>
#      </a>
#     </div>
#     <ul class="nav">
#      <li>
#       <a href="/">
#        Job Seekers Home
#       </a>
#      </li>
#      <li>
#       <a class="active" href="/job-vacancies-search-kenya">
#        Search Jobs
#       </a>
#      </li>
#      <li>
#       <a href="/employers">
#        Companies Hiring
#       </a>
#      </li>
#      <li>
#       <a href="#">
#        Employers Home
#       </a>
#       <ul>
#        <li>
#         <a href="/recruitment">
#          Our Services
#         </a>
#        </li>
#        <li>
#         <a href="/cv-library-search">
#          Find CVs
#         </a>
#        </li>
#        <li>
#         <a href="/recruitment/job-ad">
#          Job Ad Packages
#         </a>
#        </li>
#        <li>
#         <a href="/recruitment/cv-library">
#          CV Database Packages
#         </a>
#        </li>
#       </ul>
#      </li>
#      <li class="partner-link">
#       <a href="/it-freelancers">
#        IT Freelancers
#       </a>
#      </li>
#     </ul>
#    </div>
#    <!-- end Menu -->
#   </div>
#   <header>
#    <div id="header-background">
#    </div>
#    <div class="container">
#     <div class="pull-left">
#      <div id="logo">
#       <a href="/" title="Committed to employment in Kenya and in Africa">
#        <img alt="Committed to employment in Kenya and in Africa" src="/sites/kenyajob.com/themes/africawork/logo-header.png" title="Committed to employment in Kenya and in Africa"/>
#       </a>
#      </div>
#     </div>
#     <div id="slogan2">
#      <a href="/" title="Home">
#       Committed to employment in Kenya and in Africa
#      </a>
#     </div>
#     <div class="googleplay-desktop">
#      <a href="https://play.google.com/store/apps/details?id=com.africawork.mobile&amp;utm_source=application&amp;utm_campaign=mobile_app" target="_blank" title="Download our free jobs App on Google Play">
#       <img alt="Google Play" src="https://www.kenyajob.com/sites/all/themes/africawork2/images/googleplay_en-GB_h.png" typeof="foaf:Image"/>
#      </a>
#     </div>
#     <div class="googleplay-mobile">
#      <i aria-hidden="true" class="fa fa-angle-down">
#      </i>
#      <a href="https://play.google.com/store/apps/details?id=com.africawork.mobile&amp;utm_source=application&amp;utm_campaign=mobile_app" target="_blank" title="Download our free jobs App on Google Play">
#       <span class="logo">
#        <img alt="Google Play" src="https://www.kenyajob.com/sites/all/themes/africawork2/images/africawork-app-ico.png" typeof="foaf:Image"/>
#       </span>
#       <span class="txt">
#        Download our free jobs App
#        <br/>
#        on Google Play
#       </span>
#       <span class="btn-install">
#        Install
#       </span>
#      </a>
#     </div>
#     <div class="menu-user-menu block" id="menu-user-menu">
#      <div class="menu-user-menu-inner gutter" id="menu-user-menu-inner">
#       <ul class="inline">
#        <li class="menu-1226 first">
#         <a href="/login" id="ema-log-in">
#          Log In
#         </a>
#        </li>
#        <li class="menu-1217 last">
#         <a href="/register" id="ema-sign-up">
#          Register
#         </a>
#        </li>
#       </ul>
#      </div>
#      <!-- /menu-user-menu-inner -->
#     </div>
#     <!-- /menu-user-menu -->
#     <div class="pull-right" id="menu-open">
#      <a class="fm-button">
#       <i class="fa fa-bars fa-lg">
#       </i>
#      </a>
#     </div>
#     <div id="header-bottom">
#      <div id="primary-menu-wrapper">
#       <div class="primary-menu block" id="primary-menu">
#        <div class="primary-menu-inner gutter" id="primary-menu-inner">
#         <ul class="nav">
#          <li class="partner-link li-item-candidate first">
#           <a class="item-candidate" href="/it-freelancers" target="_blank">
#            IT Freelancers
#           </a>
#          </li>
#          <li class="home-link li-item-candidate">
#           <a class="item-candidate" href="/">
#            Job Seekers Home
#           </a>
#          </li>
#          <li class="jobsearch-link active-trail li-item-candidate active">
#           <a class="item-candidate active-trail active" href="/job-vacancies-search-kenya">
#            Search Jobs
#           </a>
#          </li>
#          <li class="employers-link li-item-candidate">
#           <a class="item-candidate" href="/employers">
#            Companies Hiring
#           </a>
#          </li>
#          <li class="recruiter-home-link li-item-candidate last">
#           <a class="item-candidate" href="/recruitment">
#            Employers Home
#           </a>
#          </li>
#         </ul>
#        </div>
#        <!-- /primary-menu-inner -->
#       </div>
#       <!-- /primary-menu -->
#      </div>
#     </div>
#    </div>
#   </header>
#   <section class="ba" id="main-content">
#    <!-- Container bloc header -->
#    <div class="block-header">
#     <!-- Container bloc title -->
#     <div class="bloc-title">
#      <h1 class="title">
#       IT, software engineering, Internet Jobs Kenya
#      </h1>
#      <div class="description">
#       <h4>
#        <form accept-charset="UTF-8" action="/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133" class="search-form" id="search-form" method="post">
#         <div>
#          <div class="container-inline form-wrapper" id="edit-basic">
#           <div class="form-item form-keys form-type-textfield form-item-keys" id="edit-keys-wrapper">
#            <label for="edit-keys">
#             Enter your keywords
#            </label>
#            <input class="form-text" id="edit-keys" maxlength="255" name="keys" size="15" title="Enter the terms you wish to search for." type="text" value=""/>
#           </div>
#           <input class="btn btn-primary form-submit" id="edit-submit" name="op" type="submit" value="Search"/>
#           <input name="get" type="hidden" value='{"f":["im_field_offre_secteur:133"]}'/>
#           <div class="form-item form-retain-filters form-type-checkbox form-item-retain-filters" id="edit-retain-filters-wrapper">
#            <input class="form-checkbox" id="edit-retain-filters" name="retain-filters" type="checkbox" value="1"/>
#            <label class="option" for="edit-retain-filters">
#             Retain current filters
#            </label>
#           </div>
#          </div>
#          <input name="form_build_id" type="hidden" value="form-zTWfgjHb6CHzf5RdHVTBcJnHAt6s4k_HXpx5neDf36M"/>
#          <input name="form_id" type="hidden" value="emasearch_page_search_form"/>
#         </div>
#        </form>
#        <div class="filter-wrapper">
#         <span class="btn-filter">
#          Filter
#         </span>
#        </div>
#        <div class="current-search">
#         <div class="current-search-item current-search-item-emasearch-text current-search-item-jobsearch-text-results">
#          <h3 class="">
#           54 éléments trouvé.
#          </h3>
#         </div>
#         <div class="current-search-item current-search-item-recruiter current-search-item-recruiter-title-active-items">
#          <div class="item-list">
#           <ul class="">
#            <li class="first last">
#             <a class="" href="/job-vacancies-search-kenya/" rel="nofollow">
#              IT, software engineering, Internet
#              <span class="element-invisible">
#               Apply IT, software engineering, Internet filter
#              </span>
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#       </h4>
#      </div>
#     </div>
#     <!-- End Container bloc title -->
#     <div id="banner728-90">
#      <div class="inner clearfix">
#       <div class="content clearfix">
#        <a href="https://www.kenyajob.com/job-vacancies-search-kenya?fq%5B0%5D=is_recruiter_nid%3A114673" onclick='trackOutboundLink("https://www.kenyajob.com/job-vacancies-search-kenya?fq%5B0%5D=is_recruiter_nid%3A114673", "outbound", "click");' rel="nofollow" target="_blank">
#         <img alt="" src="https://www.kenyajob.com/sites/kenyajob.com/files/728x90_gif_banner_africashore_it_vacancies_africa_white_vf.gif" typeof="foaf:Image"/>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- Container page content -->
#    <div class="container-page-content">
#     <div class="content-group-inner inner" id="content-group-inner">
#     </div>
#     <!-- sidebar-second region -->
#     <div class="region-sidebar-second sidebar-second nested grid16-3 sidebar" id="sidebar-second">
#      <div class="sidebar-second-inner inner" id="sidebar-second-inner">
#       <div class="block block-facetapi first odd ema-collapsible-block" id="block-facetapi-qayivrvmh7a0ox96lnt0vnta2fc2jqnv">
#        <div class="inner clearfix">
#         <h2 class="title block-title">
#          Job category
#         </h2>
#         <div class="content clearfix">
#          <div class="collapsible-content">
#           <div class="item-list">
#            <ul class="facetapi-facetapi-emalinks facetapi-facet-im-field-offre-metiers" id="facetapi-facet-apachesolrsolr-block-im-field-offre-metiers">
#             <li class="leaf first">
#              <span class="disabled">
#               Accounting, controlling, finance (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_metiers%3A34" id="facetapi-link--45" rel="nofollow">
#               Health and social professions (1)
#               <span class="element-invisible">
#                Apply Health and social professions filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               HR, training (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_metiers%3A31" id="facetapi-link--46" rel="nofollow">
#               IT, new technologies (46)
#               <span class="element-invisible">
#                Apply IT, new technologies filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Legal (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_metiers%3A32" id="facetapi-link--47" rel="nofollow">
#               Management (5)
#               <span class="element-invisible">
#                Apply Management filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_metiers%3A33" id="facetapi-link--48" rel="nofollow">
#               Marketing, communication (6)
#               <span class="element-invisible">
#                Apply Marketing, communication filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Production, maintenance, quality (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Public buildings and works professions (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Purchases (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               R&amp;D, project management (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_metiers%3A29" id="facetapi-link--49" rel="nofollow">
#               Sales (4)
#               <span class="element-invisible">
#                Apply Sales filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Secretarial work, assistantship (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_metiers%3A35" id="facetapi-link--50" rel="nofollow">
#               Services (1)
#               <span class="element-invisible">
#                Apply Services filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Telemarketing, teleassistance (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Tourism, hotel business and catering (0)
#              </span>
#             </li>
#             <li class="leaf last">
#              <span class="disabled">
#               Transport, logistics (0)
#              </span>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- /block-inner -->
#       </div>
#       <!-- /block -->
#       <div class="block block-facetapi even ema-collapsible-block" id="block-facetapi-0m0fe0tq0rdj0zgvfl6a7penkqkb7idg">
#        <div class="inner clearfix">
#         <h2 class="title block-title">
#          Industries
#         </h2>
#         <div class="content clearfix">
#          <div class="collapsible-content">
#           <div class="item-list">
#            <ul class="facetapi-facetapi-emalinks facetapi-facet-im-field-offre-secteur" id="facetapi-facet-apachesolrsolr-block-im-field-offre-secteur">
#             <li class="leaf first">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A116" id="facetapi-link--10" rel="nofollow">
#               Advice, audit, accounting (4)
#               <span class="element-invisible">
#                Apply Advice, audit, accounting filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Aeronautics, naval (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A21" id="facetapi-link--11" rel="nofollow">
#               Agriculture, fishing, aquaculture (3)
#               <span class="element-invisible">
#                Apply Agriculture, fishing, aquaculture filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Airport and shipping services (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A18" id="facetapi-link--12" rel="nofollow">
#               Associative activities (14)
#               <span class="element-invisible">
#                Apply Associative activities filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A25" id="facetapi-link--13" rel="nofollow">
#               Banking, insurance, finance (10)
#               <span class="element-invisible">
#                Apply Banking, insurance, finance filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A27" id="facetapi-link--14" rel="nofollow">
#               Call centers, hotlines (1)
#               <span class="element-invisible">
#                Apply Call centers, hotlines filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Chemistry, petrochemistry, raw materials, mining (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A142" id="facetapi-link--15" rel="nofollow">
#               Cleaning, security, surveillance (2)
#               <span class="element-invisible">
#                Apply Cleaning, security, surveillance filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A144" id="facetapi-link--16" rel="nofollow">
#               Consumer goods (1)
#               <span class="element-invisible">
#                Apply Consumer goods filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A117" id="facetapi-link--17" rel="nofollow">
#               Distribution, selling, wholesale (9)
#               <span class="element-invisible">
#                Apply Distribution, selling, wholesale filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Edition, printing (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A119" id="facetapi-link--18" rel="nofollow">
#               Education, training (2)
#               <span class="element-invisible">
#                Apply Education, training filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A123" id="facetapi-link--19" rel="nofollow">
#               Electric, electronic, optical and precision equipments (2)
#               <span class="element-invisible">
#                Apply Electric, electronic, optical and precision equipments filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A120" id="facetapi-link--20" rel="nofollow">
#               Electricity, water, gas, nuclear, energy (5)
#               <span class="element-invisible">
#                Apply Electricity, water, gas, nuclear, energy filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A134" id="facetapi-link--21" rel="nofollow">
#               Engineering, development studies (2)
#               <span class="element-invisible">
#                Apply Engineering, development studies filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Environment, recycling (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A127" id="facetapi-link--22" rel="nofollow">
#               Event, receptionist (1)
#               <span class="element-invisible">
#                Apply Event, receptionist filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Food-processing industry (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Furnishing, decoration (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Government services (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Greenways, forests, hunting (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Handling (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A147" id="facetapi-link--23" rel="nofollow">
#               Health, pharmacy, hospitals, medical equipment (5)
#               <span class="element-invisible">
#                Apply Health, pharmacy, hospitals, medical equipment filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A128" id="facetapi-link--24" rel="nofollow">
#               Hotel business, catering (1)
#               <span class="element-invisible">
#                Apply Hotel business, catering filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Import-export business (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A132" id="facetapi-link--25" rel="nofollow">
#               Industry, production, manufacturing and other (4)
#               <span class="element-invisible">
#                Apply Industry, production, manufacturing and other filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <div id="apachesolr-unclick-text">
#               IT, software engineering, Internet
#              </div>
#              <div id="apachesolr-unclick-link">
#               <a class="apachesolr-unclick" href="/job-vacancies-search-kenya/">
#                .
#               </a>
#              </div>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A137" id="facetapi-link--27" rel="nofollow">
#               Luxury, cosmetics (1)
#               <span class="element-invisible">
#                Apply Luxury, cosmetics filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A138" id="facetapi-link--28" rel="nofollow">
#               Maintenance, servicing, after-sales services (3)
#               <span class="element-invisible">
#                Apply Maintenance, servicing, after-sales services filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A140" id="facetapi-link--29" rel="nofollow">
#               Marketing, communication, media (8)
#               <span class="element-invisible">
#                Apply Marketing, communication, media filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A124" id="facetapi-link--30" rel="nofollow">
#               Mechanical equipment, machines (3)
#               <span class="element-invisible">
#                Apply Mechanical equipment, machines filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Metallurgy, steel industry (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A24" id="facetapi-link--31" rel="nofollow">
#               Motor, transportation equipment, reparation (1)
#               <span class="element-invisible">
#                Apply Motor, transportation equipment, reparation filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Paper, wood, rubber, plastic, glass, tobacco (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A131" id="facetapi-link--32" rel="nofollow">
#               Pharmaceutical industry (6)
#               <span class="element-invisible">
#                Apply Pharmaceutical industry filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Public buildings and works sector, construction (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Quality, methods (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Real-estate, architecture, town planning (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Rental (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A146" id="facetapi-link--33" rel="nofollow">
#               Research and development (2)
#               <span class="element-invisible">
#                Apply Research and development filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A148" id="facetapi-link--34" rel="nofollow">
#               Secretarial work (3)
#               <span class="element-invisible">
#                Apply Secretarial work filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A150" id="facetapi-link--35" rel="nofollow">
#               Services other (6)
#               <span class="element-invisible">
#                Apply Services other filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A151" id="facetapi-link--36" rel="nofollow">
#               Social, public and human services (15)
#               <span class="element-invisible">
#                Apply Social, public and human services filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Sports, cultural and social action (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Telecom (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Temporary work, recruitment (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Textile, leather, shoes, clothing industry (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A155" id="facetapi-link--37" rel="nofollow">
#               Tourism, leisure activities (1)
#               <span class="element-invisible">
#                Apply Tourism, leisure activities filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf last">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_secteur%3A156" id="facetapi-link--38" rel="nofollow">
#               Transport, logistics, postal services (1)
#               <span class="element-invisible">
#                Apply Transport, logistics, postal services filter
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- /block-inner -->
#       </div>
#       <!-- /block -->
#       <div class="block block-facetapi odd ema-collapsible-block" id="block-facetapi-oxobk0e1ydp2i4yufnkbnnbxkjgwy8vt">
#        <div class="inner clearfix">
#         <h2 class="title block-title">
#          Education Level
#         </h2>
#         <div class="content clearfix">
#          <div class="collapsible-content">
#           <div class="item-list">
#            <ul class="facetapi-facetapi-emalinks facetapi-facet-im-field-offre-niveau-etude" id="facetapi-facet-apachesolrsolr-block-im-field-offre-niveau-etude">
#             <li class="leaf first">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_niveau_etude%3A50" id="facetapi-link--51" rel="nofollow">
#               College (2)
#               <span class="element-invisible">
#                Apply College filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_niveau_etude%3A51" id="facetapi-link--52" rel="nofollow">
#               Technical school (2)
#               <span class="element-invisible">
#                Apply Technical school filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_niveau_etude%3A52" id="facetapi-link--53" rel="nofollow">
#               Bachelor (43)
#               <span class="element-invisible">
#                Apply Bachelor filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_niveau_etude%3A53" id="facetapi-link--54" rel="nofollow">
#               High school (1)
#               <span class="element-invisible">
#                Apply High school filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_niveau_etude%3A54" id="facetapi-link--55" rel="nofollow">
#               Master (6)
#               <span class="element-invisible">
#                Apply Master filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Doctorate (0)
#              </span>
#             </li>
#             <li class="leaf last">
#              <span class="disabled">
#               HND (0)
#              </span>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- /block-inner -->
#       </div>
#       <!-- /block -->
#       <div class="block block-facetapi even ema-collapsible-block" id="block-facetapi-vmglnefysjcl0qbebzgogkeyyag2fvey">
#        <div class="inner clearfix">
#         <h2 class="title block-title">
#          Experience Level
#         </h2>
#         <div class="content clearfix">
#          <div class="collapsible-content">
#           <div class="item-list">
#            <ul class="facetapi-facetapi-emalinks facetapi-facet-im-field-offre-niveau-experience" id="facetapi-facet-apachesolrsolr-block-im-field-offre-niveau-experience">
#             <li class="leaf first">
#              <span class="disabled">
#               No experience (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Less than 2 years (0)
#              </span>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_niveau_experience%3A70" id="facetapi-link--42" rel="nofollow">
#               2 to 5 years (12)
#               <span class="element-invisible">
#                Apply 2 to 5 years filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_niveau_experience%3A71" id="facetapi-link--43" rel="nofollow">
#               5 to 10 years (41)
#               <span class="element-invisible">
#                Apply 5 to 10 years filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf last">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_niveau_experience%3A72" id="facetapi-link--44" rel="nofollow">
#               More than 10 years (1)
#               <span class="element-invisible">
#                Apply More than 10 years filter
#               </span>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- /block-inner -->
#       </div>
#       <!-- /block -->
#       <div class="block block-facetapi odd ema-collapsible-block" id="block-facetapi-ax1fjqgbrrmuaedewmkzq0ghlinpwzxo">
#        <div class="inner clearfix">
#         <h2 class="title block-title">
#          Job type
#         </h2>
#         <div class="content clearfix">
#          <div class="collapsible-content">
#           <div class="item-list">
#            <ul class="facetapi-facetapi-emalinks facetapi-facet-im-field-offre-contrat-type" id="facetapi-facet-apachesolrsolr-block-im-field-offre-contrat-type">
#             <li class="leaf first">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_contrat_type%3A43" id="facetapi-link--56" rel="nofollow">
#               Fixed-term contract (49)
#               <span class="element-invisible">
#                Apply Fixed-term contract filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_contrat_type%3A42" id="facetapi-link--57" rel="nofollow">
#               Permanent contract (49)
#               <span class="element-invisible">
#                Apply Permanent contract filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_contrat_type%3A46" id="facetapi-link--58" rel="nofollow">
#               Freelance (39)
#               <span class="element-invisible">
#                Apply Freelance filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_contrat_type%3A48" id="facetapi-link--59" rel="nofollow">
#               Part-time work (2)
#               <span class="element-invisible">
#                Apply Part-time work filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_contrat_type%3A44" id="facetapi-link--60" rel="nofollow">
#               Temporary work (1)
#               <span class="element-invisible">
#                Apply Temporary work filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <span class="disabled">
#               Cooperative Education Program (0)
#              </span>
#             </li>
#             <li class="leaf last">
#              <span class="disabled">
#               Internship (0)
#              </span>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <!-- /block-inner -->
#       </div>
#       <!-- /block -->
#       <div class="block block-facetapi even ema-collapsible-block" id="block-facetapi-nskor1kswgvbowzszx9va0wwqfhdtpge">
#        <div class="inner clearfix">
#         <h2 class="title block-title">
#          Regions
#         </h2>
#         <div class="content clearfix">
#          <div class="collapsible-content">
#           <div class="item-list">
#            <ul class="facetapi-facetapi-emalinks facetapi-facet-im-field-offre-region" id="facetapi-facet-apachesolrsolr-block-im-field-offre-region">
#             <li class="leaf first">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_region%3A57" id="facetapi-link" rel="nofollow">
#               Central (49)
#               <span class="element-invisible">
#                Apply Central filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
#              <a class="facetapi-inactive" href="/job-vacancies-search-kenya/?f%5B0%5D=im_field_offre_secteur%3A133&amp;f%5B1%5D=im_field_offre_region%3A58" id="facetapi-link--2" rel="nofollow">
#               Coast (49)
#               <span class="element-invisible">
#                Apply Coast filter
#               </span>
#              </a>
#             </li>
#             <li class="leaf">
# ...
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textmauritanie">
#                  Mauritania
#                 </span>
#                </a>
#               </li>
#               <li class="benin">
#                <a href="https://www.emploibenin.com" rel="external nofollow" target="_blank">
#                 <span class="bg-benin">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textbenin">
#                  Benin
#                 </span>
#                </a>
#               </li>
#               <li class="mali">
#                <a href="https://www.emploimali.com" rel="external nofollow" target="_blank">
#                 <span class="bg-mali">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textmali">
#                  Mali
#                 </span>
#                </a>
#               </li>
#               <li class="rdc">
#                <a href="https://www.emploi.cd" rel="external nofollow" target="_blank">
#                 <span class="bg-rdc">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textrdc">
#                  DRC Congo
#                 </span>
#                </a>
#               </li>
#               <li class="algeria">
#                <a href="https://www.algeriejob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-algeria">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textalgeria">
#                  Algeria
#                 </span>
#                </a>
#               </li>
#               <li class="tunisia">
#                <a href="https://www.emploitunisie.com" rel="external nofollow" target="_blank">
#                 <span class="bg-tunisia">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="texttunisia">
#                  Tunisia
#                 </span>
#                </a>
#               </li>
#               <li class="niger">
#                <a href="https://www.nigerjob.net" rel="external nofollow" target="_blank">
#                 <span class="bg-niger">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textniger">
#                  Niger
#                 </span>
#                </a>
#               </li>
#               <li class="chad">
#                <a href="https://www.emploi.td" rel="external nofollow" target="_blank">
#                 <span class="bg-chad">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textchad">
#                  Chad
#                 </span>
#                </a>
#               </li>
#               <li class="burundi">
#                <a href="https://www.emploi.bi" rel="external nofollow" target="_blank">
#                 <span class="bg-burundi">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textburundi">
#                  Burundi
#                 </span>
#                </a>
#               </li>
#               <li class="ghana">
#                <a href="https://www.ghanajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-ghana">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textghana">
#                  Ghana
#                 </span>
#                </a>
#               </li>
#               <li class="nigeria">
#                <a href="https://www.nigeriajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-nigeria">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textnigeria">
#                  Nigeria
#                 </span>
#                </a>
#               </li>
#               <li class="egypt">
#                <a href="https://www.3amal.com" rel="external nofollow" target="_blank">
#                 <span class="bg-egypt">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textegypt">
#                  Egypt
#                 </span>
#                </a>
#               </li>
#               <li class="ethiopia">
#                <a href="https://www.ethiopiawork.com" rel="external nofollow" target="_blank">
#                 <span class="bg-ethiopia">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textethiopia">
#                  Ethiopia
#                 </span>
#                </a>
#               </li>
#               <li class="kenya">
#                <a href="https://www.kenyajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-kenya">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textkenya">
#                  Kenya
#                 </span>
#                </a>
#               </li>
#               <li class="uganda">
#                <a href="https://www.ugandajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-uganda">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textuganda">
#                  Uganda
#                 </span>
#                </a>
#               </li>
#               <li class="rwanda">
#                <a href="https://www.rwandajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-rwanda">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textrwanda">
#                  Rwanda
#                 </span>
#                </a>
#               </li>
#               <li class="tanzania">
#                <a href="https://www.tanzajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-tanzania">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="texttanzania">
#                  Tanzania
#                 </span>
#                </a>
#               </li>
#               <li class="sudan">
#                <a href="https://www.sudancareers.com" rel="external nofollow" target="_blank">
#                 <span class="bg-sudan">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textsudan">
#                  Sudan
#                 </span>
#                </a>
#               </li>
#               <li class="botswana">
#                <a href="https://www.botswajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-botswana">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textbotswana">
#                  Botswana
#                 </span>
#                </a>
#               </li>
#               <li class="malawi">
#                <a href="https://www.malawijob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-malawi">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textmalawi">
#                  Malawi
#                 </span>
#                </a>
#               </li>
#               <li class="namibia">
#                <a href="https://www.namijob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-namibia">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textnamibia">
#                  Namibia
#                 </span>
#                </a>
#               </li>
#               <li class="zambia">
#                <a href="https://www.zambiajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-zambia">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textzambia">
#                  Zambia
#                 </span>
#                </a>
#               </li>
#               <li class="zimbabwe">
#                <a href="https://www.zimbajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-zimbabwe">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textzimbabwe">
#                  Zimbabwe
#                 </span>
#                </a>
#               </li>
#               <li class="liberia">
#                <a href="https://www.liberiawork.com" rel="external nofollow" target="_blank">
#                 <span class="bg-liberia">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textliberia">
#                  Liberia
#                 </span>
#                </a>
#               </li>
#               <li class="sierraleone">
#                <a href="https://www.sierraleonejob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-sierraleone">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textsierraleone">
#                  Sierra Leone
#                 </span>
#                </a>
#               </li>
#               <li class="southafrica">
#                <a href="https://www.zajob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-southafrica">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textsouthafrica">
#                  South Africa
#                 </span>
#                </a>
#               </li>
#               <li class="southsudan">
#                <a href="https://www.southsudanjob.com" rel="external nofollow" target="_blank">
#                 <span class="bg-southsudan">
#                 </span>
#                 <span class="labelcountry">
#                  Job
#                 </span>
#                 <span class="textsouthsudan">
#                  South Sudan
#                 </span>
#                </a>
#               </li>
#               <li class="centralafrican">
#                <a href="https://www.emploi.cf" rel="external nofollow" target="_blank">
#                 <span class="bg-cenralafrican">
#                 </span>
#                 <span class="labelcountrycentralafrican">
#                  Job
#                 </span>
#                 <span class="textcentralafrican">
#                  Central African Republic
#                 </span>
#                </a>
#               </li>
#              </ul>
#              <div class="footer_message1">
#               <div class="row">
#                <ul class="links">
#                 <li class="first">
#                  <span>
#                   Copyright ©2018 Africawork.com - All rights reserved
#                   <span>
#                   </span>
#                  </span>
#                 </li>
#                 <li class="last">
#                  <span>
#                   Let´s Encrypt SSL Certificate Secured
#                  </span>
#                 </li>
#                </ul>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <!-- /footer-afrik -->
#           <div id="credits">
#            <div class="menu-informations2 region fusion-inline-menu " id="menu-informations2">
#             <div class="menu-informations2-inner inner clearfix" id="menu-informations2-inner">
#              <ul class="menu">
#               <li class="menu-2421 first">
#                <a href="/terms-conditions-of-use" title="Terms &amp; Conditions of Use">
#                 Terms &amp; Conditions of Use
#                </a>
#               </li>
#               <li class="menu-1635">
#                <a href="/terms-conditions-of-sale" title="Terms &amp; Conditions of Use &amp; Sale">
#                 Terms &amp; Conditions of Sale
#                </a>
#               </li>
#               <li class="menu-1632">
#                <a href="/legal-notices" title="Legal Notices">
#                 Legal Notices
#                </a>
#               </li>
#               <li class="menu-1637 last">
#                <a href="/intellectual-property" title="Intellectual Property">
#                 Intellectual Property
#                </a>
#               </li>
#              </ul>
#             </div>
#            </div>
#            <div class="footer_message2">
#             <div class="row">
#              Copyright ©2023 Africawork - All rights reserved
#             </div>
#            </div>
#           </div>
#          </div>
#          <!-- /footer-group -->
#         </div>
#         <!-- /footer-group-wrapper -->
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </footer>
#   <script>
#    (function ($) {
#         $selectGoTo = $('.show-mobile select');
#         $this = "";
#         var linkGoTo = "";
#         $selectGoTo.change(function(e){
#             $this = $(this);
#             linkGoTo = $this.find(':selected').data('goto');
#             if(linkGoTo){
#                 window.open(linkGoTo, '_blank');
#             }
#         });
#         $("#menu-open").click(function () {
#             //cacher le menu et sous menu horizental
#             $("#primary-menu").hide();
#             $("#secondary-menu").hide();
#             //ajuster le logo
#             //$("#logo").css('padding-bottom','33px');
#             //ajuster la croix
#             $(".button-close").css('padding-right', '15px');
#             //affichage le block sous menu actif
#             if ($(".nav > li li").hasClass("active")) {
#                 $(".nav > li li.active").parents().css("display", "block");
#             }
#             //selectionner l element actif
#             $(".nav > li li a").css("color", "#ffffff");
#             $(".nav > li li.active a").css("color", "#14b1bb");
#
#         });
#
# ///action en click du bouton close
#         $("#button-close").click(function () {
#             //affiche le menu et sous menu horizontal
#             $("#primary-menu").show();
#             $("#secondary-menu").show();
#             //ajuster le logo
#             //$("#logo").css('padding-bottom','33px');
#         });
# //action afficher plus de cvs
#         $("#more-cvs .more").click(function () {
#             $(".hidden-cvs").css('display', 'inline-block');
#             $("#more-cvs .more").hide();
#             $("#more-cvs .less").show();
#         });
# //action cacher les cvs
#         $("#more-cvs .less").click(function () {
#             $(".hidden-cvs").css('display', 'none');
#             $("#more-cvs .more").show();
#             $("#more-cvs .less").hide();
#         });
#         $(document).ready(function () {
#             //ouvrir l'element parent du menu vertical
#             if ($(".menu-left li").hasClass("active")) {
#                 $(".menu-left li.active > ul").css("display", "block");
#             }
#
#             $('#ema-products-features').each(function () {
#                 $('abbr').renameAttr('data-tip', 'title', 'false');
#             });
#
#         });
#
#
#     })(jQuery);
#   </script>
#   <div data-id="0" data-status="nc" id="mobile-data" style="display: none">
#   </div>
#  </body>
# </html>

# %% [markdown]
# ## <font color='#2F4F4F'>Step 3: Extracting Required Elements</font>

# %%
# 1. Extracting job titles and links: pigia me
# ---
# 
Jobs = pigia.find_all('div', {'class': 'listings-cards__list-item'})

titles = []
links = []

for job in results:
    title = job.find('div', 'listing-card__header__title').get_text().strip()
    if title is not None:
        link =  job.a.get('href')
        titles.append(title)
        links.append(link)

df_pigia_me = pd.DataFrame({'Pigia Me Job Title': titles, 'Pigia Me link': links})
print(df_pigia_me)
# Out:
#                                   Pigia Me Job Title  \
# 0                                 Software Developer
# 1  Software Development Java, nodeJs (Onsite Nyer...
# 2                         Frontend Developer Reframe
# 3                                  Chatbot Developer
# 4                         Assistant IT Administrator
# 5                                 Frontend Developer
# 6                                        CRM Enginee
# 7                                 Analyst Programmer
# 8                              Senior Game Developer
# 9                           Lead Full Stack Engineer
#
#                                        Pigia Me link
# 0  https://www.pigiame.co.ke/listings/software-de...
# 1  https://www.pigiame.co.ke/listings/software-de...
# 2  https://www.pigiame.co.ke/listings/frontend-de...
# 3  https://www.pigiame.co.ke/listings/chatbot-dev...
# 4  https://www.pigiame.co.ke/listings/assistant-i...
# 5  https://www.pigiame.co.ke/listings/frontend-de...
# 6  https://www.pigiame.co.ke/listings/crm-enginee...
# 7  https://www.pigiame.co.ke/listings/analyst-pro...
# 8  https://www.pigiame.co.ke/listings/senior-game...
# 9  https://www.pigiame.co.ke/listings/lead-full-s...

# %%
# 2. Extracting job titles: my_job_mag
# ---

Jobs = MJM.find_all('li', {'class': 'job-info'})

titles = []
links = []

for job in Jobs:
    title = job.find('h2').get_text().strip()
    if title is not None:
        link =  job.h2.a.get('href')
        titles.append(title)
        links.append(link)

df_MJM = pd.DataFrame({'My_Job_Mag Job Title': titles})
print(df_MJM)
# Out:
#                                  My_Job_Mag Job Title
# 0   Performance Quality Engineer (SRE) at Koko Net...
# 1             Senior DevOps Engineer at Koko Networks
# 2   Senior Application Developer at Techsavanna Te...
# 3   Technical Architect at Techsavanna Technology ...
# 4   Customer Support Analyst II, VisionFund Intern...
# 5   Junior Business Intelligence Developers at Dav...
# 6             IT Officer - Attachment at CORAT Africa
# 7   Software Engineering – Cloud and AI - Masters/...
# 8   Application Developer at Techsavanna Technolog...
# 9   Senior Application Developer at Techsavanna Te...
# 10  Technical Architect at Techsavanna Technology ...
# 11  Business Architect at Techsavanna Technology L...
# 12  Enterprise Solution Engineer at Techsavanna Te...
# 13  Learning Designer at African Management Instit...
# 14  Lecturer - Computer Science at Kenya Methodist...
# 15  Senior Lecturers- Computer science at Kenya Me...
# 16        I.T Assistant at SABIS International School
# 17        CVM Development Engineer at Safaricom Kenya

# %%
# 3. Extracting job titles: kenya_job
# ---
#KenyanJob

import pandas as pd             # library for data manupation
import requests                 # library for fetching a web page 
from bs4 import BeautifulSoup   # library for extrating contents from a webpage

KenyanJob = 'https://www.kenyajob.com/job-vacancies-search-kenya?f%5B0%5D=im_field_offre_secteur%3A133'
response = requests.get(KenyanJob)
soup = BeautifulSoup(response.content, 'html.parser')

kenya_jobs = soup.find_all('div', {'class': 'col-lg-5 col-md-5 col-sm-5 col-xs-12 job-title'})

titles = []
links = []

for job in kenya_jobs:
    title = job.find('h5').get_text().strip()
    if title is not None:
        link =  job.h5.a.get('href')
        titles.append(title)
        links.append(link)

KenyanJob_df = pd.DataFrame({'KenyanJob Job Title': titles})
print(KenyanJob_df)
# Out:
#                                   KenyanJob Job Title
# 0          JAVA EE / JAVA 8 Developer with SQL Skills
# 1                       Senior Freelance Web Designer
# 2             CCTV and Fire Alarms Systems Technician
# 3             Information Technology Sales Specialist
# 4                           AWS Cloud Architect (M/F)
# 5                       AWS Solutions Architect (M/F)
# 6                     AZURE Solutions Architect (M/F)
# 7                               Cloud Architect (M/F)
# 8   Cloud Computing and Virtualization Engineer (M/F)
# 9                                Cloud Engineer (M/F)
# 10                Cloud Microservices Architect (M/F)
# 11                   Cloud System Administrator (M/F)
# 12                      Cloud System Integrator (M/F)
# 13                      Cyber Security Engineer (M/F)
# 14                          DATASTAGE Architect (M/F)
# 15                            GENESYS Architect (M/F)
# 16                            Network Architect (M/F)
# 17                            ANGULAR Developer (M/F)
# 18                              DevOps Engineer (M/F)
# 19                             DOTNET Developer (M/F)
# 20                                IOS Developer (M/F)
# 21                               JAVA Developer (M/F)
# 22                           JAVA JEE Developer (M/F)
# 23                         JAVASCRIPT Developer (M/F)
# 24                             KOTLIN Developer (M/F)

# %% [markdown]
# ## <font color='#2F4F4F'>Step 4: Saving our Data</font>

# %%
# Saving the scraped contents in a dataframe and preview our data
# ---
#
Combined_data = pd.concat([df_pigia_me, df_MJM, KenyanJob_df], axis=1)
Combined_data.head()
# Out:
#                                   Pigia Me Job Title  \
# 0                                 Software Developer
# 1  Software Development Java, nodeJs (Onsite Nyer...
# 2                         Frontend Developer Reframe
# 3                                  Chatbot Developer
# 4                         Assistant IT Administrator
#
#                                        Pigia Me link  \
# 0  https://www.pigiame.co.ke/listings/software-de...
# 1  https://www.pigiame.co.ke/listings/software-de...
# 2  https://www.pigiame.co.ke/listings/frontend-de...
# 3  https://www.pigiame.co.ke/listings/chatbot-dev...
# 4  https://www.pigiame.co.ke/listings/assistant-i...
#
#                                 My_Job_Mag Job Title  \
# 0  Performance Quality Engineer (SRE) at Koko Net...
# 1            Senior DevOps Engineer at Koko Networks
# 2  Senior Application Developer at Techsavanna Te...
# 3  Technical Architect at Techsavanna Technology ...
# 4  Customer Support Analyst II, VisionFund Intern...
#
#                           KenyanJob Job Title
# 0  JAVA EE / JAVA 8 Developer with SQL Skills
# 1               Senior Freelance Web Designer
# 2     CCTV and Fire Alarms Systems Technician
# 3     Information Technology Sales Specialist
# 4                   AWS Cloud Architect (M/F)
